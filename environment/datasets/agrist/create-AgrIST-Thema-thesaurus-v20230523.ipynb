# %% [markdown]
# # ISSA-2: convert the AgrIST-Thema thesaurus from the Excel to RDF
#
# Note: *rdflib* does not output the triples in the order they are added, we slightly modify the serialization from a straight forward way.

# %%
import pandas as pd
from rdflib import Graph, Literal, RDF, URIRef, Namespace
from rdflib.namespace import DC, RDF, SKOS, RDFS, DCTERMS, XSD, VOID, DCAT
import datetime
import re

# %%
agrist_fn = 'Plan de catégorisation AgrIST-Thema-20230523.xlsx'
agrist_df = pd.read_excel(agrist_fn, 0, 
                          usecols='A:H',
                          names=['category',  'category-label-fr', 'category-label-en',
                                 'sub-category', 'sub-category-label-fr', 'sub-category-label-en',
                                 'scopeNote', 'editorialNote'],
                          index_col=None)

schema_title_en = u'AgrIST-Thema categorization scheme'
schema_title_fr = u'Plan de classement AgrIST-Thema'

# this comment is needed to put the rdfs prefix as early as posible 
schema_comment = u'Nouveau plan de classement Agris-Agritrop (version du 23 mai 2023)'

schema_creator     = 'https://ror.org/05kpkpg04' #CIRAD
schema_contributor = 'https://ror.org/02kvxyf05' #INRIA

schema_version = '2023.05.23'
schema_created = '2023-06-29'
schema_issued  = '2023-06-29'
schema_modified = datetime.datetime.now().strftime('%Y-%m-%d')

schema_license = 'http://opendatacommons.org/licenses/by/1.0'
schema_access =  'http://purl.org/eprint/accessRights/OpenAccess'

sparql_endpoint = 'https://data-issa.cirad.fr/sparql'

agrist_ttl = 'AgrIST-Thema-v20230523.ttl'
agrist_ns = 'http://dist.cirad.fr/agrist-thema/'

# %%
agrist_df['category'] = agrist_df['category'].fillna(method='ffill')
agrist_df['category-label-fr'] = agrist_df['category-label-fr'].fillna(method='ffill')
agrist_df['category-label-en'] = agrist_df['category-label-en'].fillna(method='ffill')
agrist_df = agrist_df.dropna(subset='sub-category').apply(lambda x: x.str.strip()).fillna('')
#agrist_df['category'] = agrist_df['sub-category'].str[0]

# %%
agrist_df
# Out:
#     category                           category-label-fr  \
# 1          A                                 AGRICULTURE
# 2          A                                 AGRICULTURE
# 4          B                      GÉOGRAPHIE ET HISTOIRE
# 5          B                      GÉOGRAPHIE ET HISTOIRE
# 7          C  ENSEIGNEMENT, VULGARISATION ET INFORMATION
# ..       ...                                         ...
# 131        U                      SCIENCES ET TECHNIQUES
# 132        U                      SCIENCES ET TECHNIQUES
# 133        U                      SCIENCES ET TECHNIQUES
# 134        U                      SCIENCES ET TECHNIQUES
# 135        U                      SCIENCES ET TECHNIQUES
#
#                         category-label-en sub-category  \
# 1                             AGRICULTURE          A01
# 2                             AGRICULTURE          A50
# 4                   GEOGRAPHY AND HISTORY          B10
# 5                   GEOGRAPHY AND HISTORY          B50
# 7    EDUCATION, EXTENSION AND INFORMATION          C10
# ..                                    ...          ...
# 131                SCIENCE AND TECHNOLOGY          U10
# 132                SCIENCE AND TECHNOLOGY          U30
# 133                SCIENCE AND TECHNOLOGY          U50
# 134                SCIENCE AND TECHNOLOGY          U60
# 135                SCIENCE AND TECHNOLOGY          U70
#
#                            sub-category-label-fr  \
# 1         Agriculture - Considérations générales
# 2                          Recherche agronomique
# 4                                     Géographie
# 5                                       Histoire
# 7                                   Enseignement
# ..                                           ...
# 131  Informatique, mathématiques et statistiques
# 132          Méthodes et techniques de recherche
# 133                 Sciences physiques et chimie
# 134            Sciences de la vie et de la Terre
# 135                Sciences humaines et sociales
#
#                             sub-category-label-en  \
# 1                   Agriculture - General aspects
# 2                           Agricultural research
# 4                                       Geography
# 5                                         History
# 7                                       Education
# ..                                            ...
# 131  Computer science, mathematics and statistics
# 132                              Research methods
# 133                Physical and chemical sciences
# 134                       Life and Earth sciences
# 135     Social sciences, economics and humanities
#
#                                              scopeNote  \
# 1    Considérations sur l'agriculture dans son sens...
# 2    Administration de la recherche agronomique en ...
# 4    Géographie physique relative à l'agriculture o...
# 5    Histoire de l'agriculture, archéologie appliqu...
# 7    Enseignement, formation, e-Learning, formation...
# ..                                                 ...
# 131  Concerne les différentes disciplines de l'info...
# 132  Considérations générales sur les méthodes et l...
# 133  Concerne les différentes disciplines de la phy...
# 134  Concerne les sciences biologiques fondamentale...
# 135  Sciences sociales : psychologie ; économie et ...
#
#                                          editorialNote
# 1
# 2    méthodes et techniques de recherche, voir U30\...
# 4    cartographie climatique et cartographie météor...
# 5
# 7    agent de vulgarisation, voir C20\ncommunicatio...
# ..                                                 ...
# 131  économétrie en général, modèles économiques, v...
# 132  administration de la recherche agricole, voir ...
# 133       biochimie, voir U60\ntélédétection, voir U30
# 134  écologie des animaux utiles, voir L20\ntélédét...
# 135  droit agricole, voir D50\ndocumentation, bibli...
#
# [120 rows x 8 columns]

# %% [markdown]
# #### start the graph with namespaces

# %%
def new_Graph(agrist_ns = 'http://dist.cirad.fr/agrist-thema/'):
    g = Graph()

    g.bind('skos', SKOS)
    g.bind('dc', DC)
    g.bind('dct', DCTERMS)
    g.bind('rdfs', RDFS)
    g.bind('dcat', DCAT)
    g.bind('void', VOID)
    g.bind('agrist', Namespace(agrist_ns))
    
    return g


# Using explicit write to the file instead of rdflib serialization to the file 
# to create a better ordered file
def serialize_Graph(g, file_name=agrist_ttl, append=False):
    if not append:

        with open(file_name, 'bw') as ttl_file:
            ttl_file.write(g.serialize(format='turtle'))
    else:

        def _remove_prefixes(g):
            return g.serialize(format="turtle").decode('utf-8').split('\n\n', maxsplit=1)[1].encode('utf-8') 

        with open(file_name, 'ba') as ttl_file:
            ttl_file.write(_remove_prefixes(g))

# %% [markdown]
# #### define schema

# %%
g = new_Graph()
schema=URIRef(agrist_ns) # URIRef('http://dist.cirad.fr/agrist-thema/AGRIS')

g.add( (schema , RDF.type, SKOS.ConceptScheme ))
g.add( (schema , RDFS.comment, Literal(schema_comment, lang='fr') ))

g.add( (schema , DC.title, Literal(schema_title_fr, lang='fr') ))
g.add( (schema , DC.title, Literal(schema_title_en, lang='en') ))


# metadata
g.add( (schema , DCTERMS.creator,     URIRef(schema_creator)    )) 
g.add( (schema , DCTERMS.contributor, URIRef(schema_contributor))) 
g.add( (schema , DCTERMS.publisher,   URIRef(schema_creator)  ))
g.add( (schema , DCTERMS.publisher,   URIRef(schema_contributor)  ))

g.add( (schema , DCTERMS.created,  Literal(schema_created, datatype=XSD.date)) )
g.add( (schema , DCTERMS.isssued,  Literal(schema_created, datatype=XSD.date)) )
g.add( (schema , DCTERMS.modified, Literal(schema_modified, datatype=XSD.date)) )

g.add( (schema , DCTERMS.license , URIRef(schema_license) )) 
g.add( (schema , DCTERMS.accessRights, URIRef(schema_access) )) 

g.add( (schema , VOID.sparqlEndpoint, URIRef(sparql_endpoint) ))
g.add( (schema , VOID.uriSpace , URIRef(agrist_ns) ))

g.add( (schema , DCAT.version , Literal(schema_version) ))

# %%
print(g.serialize(format="turtle").decode('utf-8'))
# Out:
# @prefix agrist: <http://dist.cirad.fr/agrist-thema/> .
# @prefix dc: <http://purl.org/dc/elements/1.1/> .
# @prefix dcat: <http://www.w3.org/ns/dcat#> .
# @prefix dct: <http://purl.org/dc/terms/> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix skos: <http://www.w3.org/2004/02/skos/core#> .
# @prefix void: <http://rdfs.org/ns/void#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# agrist: a skos:ConceptScheme ;
#     dc:title "AgrIST-Thema categorization scheme"@en,
#         "Plan de classement AgrIST-Thema"@fr ;
#     dct:accessRights <http://purl.org/eprint/accessRights/OpenAccess> ;
#     dct:contributor <https://ror.org/02kvxyf05> ;
#     dct:created "2023-06-29"^^xsd:date ;
#     dct:creator <https://ror.org/05kpkpg04> ;
#     dct:isssued "2023-06-29"^^xsd:date ;
#     dct:license <http://opendatacommons.org/licenses/by/1.0> ;
#     dct:modified "2023-06-29"^^xsd:date ;
#     dct:publisher <https://ror.org/02kvxyf05>,
#         <https://ror.org/05kpkpg04> ;
#     void:sparqlEndpoint <https://data-issa.cirad.fr/sparql> ;
#     void:uriSpace agrist: ;
#     rdfs:comment "Nouveau plan de classement Agris-Agritrop (version du 23 mai 2023)"@fr ;
#     dcat:version "2023.05.23" .

# %%
serialize_Graph(g, agrist_ttl)

# %% [markdown]
# #### define top concepts (categories)

# %%
g = new_Graph()
for ind, row in agrist_df.drop_duplicates(subset=['category','category-label-fr','category-label-en']).iterrows():
    
    category = URIRef(agrist_ns + row['category'])
    lbl_fr   = Literal(row['category-label-fr'], lang='fr')
    lbl_en   = Literal(row['category-label-en'], lang='en')
    
    g.add( (category , RDF.type, SKOS.Concept ))
    g.add( (category , SKOS.topConceptOf, schema ))
    g.add( (category , SKOS.prefLabel,  lbl_fr))
    g.add( (category , SKOS.prefLabel,  lbl_en))

# %%
print(g.serialize(format="turtle").decode('utf-8'))
# Out:
# @prefix agrist: <http://dist.cirad.fr/agrist-thema/> .
# @prefix skos: <http://www.w3.org/2004/02/skos/core#> .
#
# agrist:A a skos:Concept ;
#     skos:prefLabel "AGRICULTURE"@en,
#         "AGRICULTURE"@fr ;
#     skos:topConceptOf agrist: .
#
# agrist:B a skos:Concept ;
#     skos:prefLabel "GEOGRAPHY AND HISTORY"@en,
#         "GÉOGRAPHIE ET HISTOIRE"@fr ;
#     skos:topConceptOf agrist: .
#
# agrist:C a skos:Concept ;
#     skos:prefLabel "EDUCATION, EXTENSION AND INFORMATION"@en,
#         "ENSEIGNEMENT, VULGARISATION ET INFORMATION"@fr ;
#     skos:topConceptOf agrist: .
#
# agrist:D a skos:Concept ;
#     skos:prefLabel "ADMINISTRATION AND LEGISLATION"@en,
#         "ADMINISTRATION ET LÉGISLATION"@fr ;
#     skos:topConceptOf agrist: .
#
# agrist:E a skos:Concept ;
#     skos:prefLabel "ECONOMICS, DEVELOPMENT AND RURAL SOCIOLOGY"@en,
#         "ÉCONOMIE, DÉVELOPPEMENT ET SOCIOLOGIE RURALE"@fr ;
#     skos:topConceptOf agrist: .
#
# agrist:F a skos:Concept ;
#     skos:prefLabel "PLANT SCIENCE AND PRODUCTION"@en,
#         "SCIENCES ET PRODUCTION VÉGÉTALES"@fr ;
#     skos:topConceptOf agrist: .
#
# agrist:H a skos:Concept ;
#     skos:prefLabel "PLANT PROTECTION"@en,
#         "PROTECTION DES VÉGÉTAUX"@fr ;
#     skos:topConceptOf agrist: .
#
# agrist:J a skos:Concept ;
#     skos:prefLabel "POSTHARVEST TECHNOLOGY"@en,
#         "TECHNOLOGIE APRÈS RÉCOLTE"@fr ;
#     skos:topConceptOf agrist: .
#
# agrist:K a skos:Concept ;
#     skos:prefLabel "FORESTRY"@en,
#         "FORESTERIE"@fr ;
#     skos:topConceptOf agrist: .
#
# agrist:L a skos:Concept ;
#     skos:prefLabel "ANIMAL SCIENCE, PRODUCTION AND PROTECTION"@en,
#         "SCIENCES ANIMALES, PRODUCTION ET PROTECTION ANIMALES"@fr ;
#     skos:topConceptOf agrist: .
#
# agrist:M a skos:Concept ;
#     skos:prefLabel "FISHERIES AND AQUACULTURE"@en,
#         "PÊCHE ET AQUACULTURE"@fr ;
#     skos:topConceptOf agrist: .
#
# agrist:N a skos:Concept ;
#     skos:prefLabel "AGRICULTURAL MACHINERY AND ENGINEERING"@en,
#         "MACHINISME AGRICOLE ET GÉNIE RURAL"@fr ;
#     skos:topConceptOf agrist: .
#
# agrist:P a skos:Concept ;
#     skos:prefLabel "NATURAL RESOURCES AND ENVIRONMENT"@en,
#         "RESSOURCES NATURELLES ET ENVIRONNEMENT"@fr ;
#     skos:topConceptOf agrist: .
#
# agrist:Q a skos:Concept ;
#     skos:prefLabel "FOOD SCIENCE AND TECHNOLOGY"@en,
#         "SCIENCES ET TECHNOLOGIE ALIMENTAIRES"@fr ;
#     skos:topConceptOf agrist: .
#
# agrist:S a skos:Concept ;
#     skos:prefLabel "HUMAN HEALTH AND NUTRITION"@en,
#         "SANTÉ ET NUTRITION HUMAINES"@fr ;
#     skos:topConceptOf agrist: .
#
# agrist:U a skos:Concept ;
#     skos:prefLabel "SCIENCE AND TECHNOLOGY"@en,
#         "SCIENCES ET TECHNIQUES"@fr ;
#     skos:topConceptOf agrist: .

# %%
serialize_Graph(g, agrist_ttl, append=True)

# %% [markdown]
# #### define all concepts (sub-categories)

# %%
g = new_Graph()
for ind, row in agrist_df.iterrows():
    
    category = URIRef(agrist_ns + row['category'])
    sub_category = URIRef(agrist_ns + row['sub-category'])
    lbl_fr   = Literal(row['sub-category-label-fr'], lang='fr')
    lbl_en   = Literal(row['sub-category-label-en'], lang='en')
    
    g.add( (sub_category , RDF.type, SKOS.Concept ))
    g.add( (sub_category , SKOS.broader, category ))
    g.add( (sub_category , SKOS.prefLabel,  lbl_fr))
    g.add( (sub_category , SKOS.prefLabel,  lbl_en))

# %%
print(g.serialize(format="turtle").decode('utf-8'))
# Out:
# @prefix agrist: <http://dist.cirad.fr/agrist-thema/> .
# @prefix skos: <http://www.w3.org/2004/02/skos/core#> .
#
# agrist:A01 a skos:Concept ;
#     skos:broader agrist:A ;
#     skos:prefLabel "Agriculture - General aspects"@en,
#         "Agriculture - Considérations générales"@fr .
#
# agrist:A50 a skos:Concept ;
#     skos:broader agrist:A ;
#     skos:prefLabel "Agricultural research"@en,
#         "Recherche agronomique"@fr .
#
# agrist:B10 a skos:Concept ;
#     skos:broader agrist:B ;
#     skos:prefLabel "Geography"@en,
#         "Géographie"@fr .
#
# agrist:B50 a skos:Concept ;
#     skos:broader agrist:B ;
#     skos:prefLabel "History"@en,
#         "Histoire"@fr .
#
# agrist:C10 a skos:Concept ;
#     skos:broader agrist:C ;
#     skos:prefLabel "Education"@en,
#         "Enseignement"@fr .
#
# agrist:C20 a skos:Concept ;
#     skos:broader agrist:C ;
#     skos:prefLabel "Extension"@en,
#         "Vulgarisation"@fr .
#
# agrist:C30 a skos:Concept ;
#     skos:broader agrist:C ;
#     skos:prefLabel "Documentation and information"@en,
#         "Documentation et information"@fr .
#
# agrist:D10 a skos:Concept ;
#     skos:broader agrist:D ;
#     skos:prefLabel "Public administration"@en,
#         "Administration publique"@fr .
#
# agrist:D50 a skos:Concept ;
#     skos:broader agrist:D ;
#     skos:prefLabel "Legislation"@en,
#         "Législation"@fr .
#
# agrist:E10 a skos:Concept ;
#     skos:broader agrist:E ;
#     skos:prefLabel "Agricultural economics and policies"@en,
#         "Économie et politique agricoles"@fr .
#
# agrist:E11 a skos:Concept ;
#     skos:broader agrist:E ;
#     skos:prefLabel "Land economics and policies"@en,
#         "Économie et politique foncières"@fr .
#
# agrist:E12 a skos:Concept ;
#     skos:broader agrist:E ;
#     skos:prefLabel "Labour and employment"@en,
#         "Travail et emploi"@fr .
#
# agrist:E13 a skos:Concept ;
#     skos:broader agrist:E ;
#     skos:prefLabel "Investment, finance and credit"@en,
#         "Investissements, financement et crédit"@fr .
#
# agrist:E14 a skos:Concept ;
#     skos:broader agrist:E ;
#     skos:prefLabel "Development economics and policies"@en,
#         "Économie et politique du développement"@fr .
#
# agrist:E16 a skos:Concept ;
#     skos:broader agrist:E ;
#     skos:prefLabel "Production economics"@en,
#         "Économie de la production"@fr .
#
# agrist:E20 a skos:Concept ;
#     skos:broader agrist:E ;
#     skos:prefLabel "Organization, administration and management of agricultural enterprises or farms"@en,
#         "Organisation, administration et gestion des entreprises ou exploitations agricoles"@fr .
#
# agrist:E21 a skos:Concept ;
#     skos:broader agrist:E ;
#     skos:prefLabel "Agro-industry"@en,
#         "Agro-industrie"@fr .
#
# agrist:E40 a skos:Concept ;
#     skos:broader agrist:E ;
#     skos:prefLabel "Cooperatives"@en,
#         "Coopératives"@fr .
#
# agrist:E50 a skos:Concept ;
#     skos:broader agrist:E ;
#     skos:prefLabel "Rural sociology"@en,
#         "Sociologie rurale"@fr .
#
# agrist:E51 a skos:Concept ;
#     skos:broader agrist:E ;
#     skos:prefLabel "Rural population"@en,
#         "Population rurale"@fr .
#
# agrist:E70 a skos:Concept ;
#     skos:broader agrist:E ;
#     skos:prefLabel "Trade, marketing and distribution"@en,
#         "Commerce, commercialisation et distribution"@fr .
#
# agrist:E71 a skos:Concept ;
#     skos:broader agrist:E ;
#     skos:prefLabel "International trade"@en,
#         "Commerce international"@fr .
#
# agrist:E72 a skos:Concept ;
#     skos:broader agrist:E ;
#     skos:prefLabel "Domestic trade"@en,
#         "Commerce intérieur"@fr .
#
# agrist:E73 a skos:Concept ;
#     skos:broader agrist:E ;
#     skos:prefLabel "Consumer economics"@en,
#         "Économie de la consommation"@fr .
#
# agrist:E80 a skos:Concept ;
#     skos:broader agrist:E ;
#     skos:prefLabel "Home economics and crafts"@en,
#         "Économie familiale et artisanale"@fr .
#
# agrist:E90 a skos:Concept ;
#     skos:broader agrist:E ;
#     skos:prefLabel "Agrarian structure"@en,
#         "Structure agraire"@fr .
#
# agrist:F01 a skos:Concept ;
#     skos:broader agrist:F ;
#     skos:prefLabel "Plant cultivation"@en,
#         "Culture des plantes"@fr .
#
# agrist:F02 a skos:Concept ;
#     skos:broader agrist:F ;
#     skos:prefLabel "Plant propagation"@en,
#         "Multiplication végétative des plantes"@fr .
#
# agrist:F03 a skos:Concept ;
#     skos:broader agrist:F ;
#     skos:prefLabel "Seed production and processing"@en,
#         "Production et traitement des semences"@fr .
#
# agrist:F04 a skos:Concept ;
#     skos:broader agrist:F ;
#     skos:prefLabel "Fertilizing"@en,
#         "Fertilisation"@fr .
#
# agrist:F06 a skos:Concept ;
#     skos:broader agrist:F ;
#     skos:prefLabel "Irrigation"@en,
#         "Irrigation"@fr .
#
# agrist:F07 a skos:Concept ;
#     skos:broader agrist:F ;
#     skos:prefLabel "Soil cultivation"@en,
#         "Travail du sol"@fr .
#
# agrist:F08 a skos:Concept ;
#     skos:broader agrist:F ;
#     skos:prefLabel "Cropping patterns and systems"@en,
#         "Systèmes et modes de culture"@fr .
#
# agrist:F30 a skos:Concept ;
#     skos:broader agrist:F ;
#     skos:prefLabel "Plant genetics and breeding"@en,
#         "Génétique et amélioration des plantes"@fr .
#
# agrist:F40 a skos:Concept ;
#     skos:broader agrist:F ;
#     skos:prefLabel "Plant ecology"@en,
#         "Écologie végétale"@fr .
#
# agrist:F50 a skos:Concept ;
#     skos:broader agrist:F ;
#     skos:prefLabel "Plant structure"@en,
#         "Anatomie et morphologie des plantes"@fr .
#
# agrist:F60 a skos:Concept ;
#     skos:broader agrist:F ;
#     skos:prefLabel "Plant physiology and biochemistry"@en,
#         "Physiologie et biochimie végétale"@fr .
#
# agrist:F61 a skos:Concept ;
#     skos:broader agrist:F ;
#     skos:prefLabel "Plant physiology - Nutrition"@en,
#         "Physiologie végétale - Nutrition"@fr .
#
# agrist:F62 a skos:Concept ;
#     skos:broader agrist:F ;
#     skos:prefLabel "Plant physiology - Growth and development"@en,
#         "Physiologie végétale - Croissance et développement"@fr .
#
# agrist:F63 a skos:Concept ;
#     skos:broader agrist:F ;
#     skos:prefLabel "Plant physiology - Reproduction"@en,
#         "Physiologie végétale - Reproduction"@fr .
#
# agrist:F70 a skos:Concept ;
#     skos:broader agrist:F ;
#     skos:prefLabel "Plant taxonomy and geography"@en,
#         "Taxonomie végétale et phytogéographie"@fr .
#
# agrist:H01 a skos:Concept ;
#     skos:broader agrist:H ;
#     skos:prefLabel "Protection of plants - General aspects"@en,
#         "Protection des végétaux - Considérations générales"@fr .
#
# agrist:H02 a skos:Concept ;
#     skos:broader agrist:H ;
#     skos:prefLabel "Pesticides"@en,
#         "Pesticides"@fr .
#
# agrist:H10 a skos:Concept ;
#     skos:broader agrist:H ;
#     skos:prefLabel "Pests of plants"@en,
#         "Ravageurs des plantes"@fr .
#
# agrist:H20 a skos:Concept ;
#     skos:broader agrist:H ;
#     skos:prefLabel "Plant diseases"@en,
#         "Maladies des plantes"@fr .
#
# agrist:H50 a skos:Concept ;
#     skos:broader agrist:H ;
#     skos:prefLabel "Miscellaneous plant disorders"@en,
#         "Troubles divers des plantes"@fr .
#
# agrist:H60 a skos:Concept ;
#     skos:broader agrist:H ;
#     skos:prefLabel "Weeds and weed control"@en,
#         "Mauvaises herbes et désherbage"@fr .
#
# agrist:J10 a skos:Concept ;
#     skos:broader agrist:J ;
#     skos:prefLabel "Handling, transport, storage and protection of agricultural products"@en,
#         "Manutention, transport, stockage et conservation des produits agricoles"@fr .
#
# agrist:J11 a skos:Concept ;
#     skos:broader agrist:J ;
#     skos:prefLabel "Handling, transport, storage and protection of plant products"@en,
#         "Manutention, transport, stockage et conservation des produits d'origine végétale"@fr .
#
# agrist:J12 a skos:Concept ;
#     skos:broader agrist:J ;
#     skos:prefLabel "Handling, transport, storage and protection of forest products"@en,
#         "Manutention, transport, stockage et conservation des produits forestiers"@fr .
#
# agrist:J13 a skos:Concept ;
#     skos:broader agrist:J ;
#     skos:prefLabel "Handling, transport, storage and protection of animal products"@en,
#         "Manutention, transport, stockage et conservation des produits d'origine animale"@fr .
#
# agrist:J14 a skos:Concept ;
#     skos:broader agrist:J ;
#     skos:prefLabel "Handling, transport, storage and protection of fisheries and aquacultural products"@en,
#         "Manutention, transport, stockage et conservation des produits de la pêche et de l'aquaculture"@fr .
#
# agrist:J15 a skos:Concept ;
#     skos:broader agrist:J ;
#     skos:prefLabel "Handling, transport, storage and protection of non-food or non-feed agricultural products"@en,
#         "Manutention, transport, stockage et conservation des produits agricoles non-alimentaires"@fr .
#
# agrist:K01 a skos:Concept ;
#     skos:broader agrist:K ;
#     skos:prefLabel "Forestry - General aspects"@en,
#         "Foresterie - Considérations générales"@fr .
#
# agrist:K10 a skos:Concept ;
#     skos:broader agrist:K ;
#     skos:prefLabel "Forestry production"@en,
#         "Production forestière"@fr .
#
# agrist:K11 a skos:Concept ;
#     skos:broader agrist:K ;
#     skos:prefLabel "Forest engineering"@en,
#         "Génie forestier"@fr .
#
# agrist:K50 a skos:Concept ;
#     skos:broader agrist:K ;
#     skos:prefLabel "Processing of forest products"@en,
#         "Technologie des produits forestiers"@fr .
#
# agrist:K70 a skos:Concept ;
#     skos:broader agrist:K ;
#     skos:prefLabel "Forest injuries and protection"@en,
#         "Dégâts causés aux forêts et leur protection"@fr .
#
# agrist:L01 a skos:Concept ;
#     skos:broader agrist:L ;
#     skos:prefLabel "Animal husbandry"@en,
#         "Élevage - Considérations générales"@fr .
#
# agrist:L02 a skos:Concept ;
#     skos:broader agrist:L ;
#     skos:prefLabel "Animal feeding"@en,
#         "Alimentation animale"@fr .
#
# agrist:L10 a skos:Concept ;
#     skos:broader agrist:L ;
#     skos:prefLabel "Animal genetics and breeding"@en,
#         "Génétique et amélioration des animaux"@fr .
#
# agrist:L20 a skos:Concept ;
#     skos:broader agrist:L ;
#     skos:prefLabel "Animal ecology"@en,
#         "Écologie animale"@fr .
#
# agrist:L40 a skos:Concept ;
#     skos:broader agrist:L ;
#     skos:prefLabel "Animal structure"@en,
#         "Anatomie et morphologie des animaux"@fr .
#
# agrist:L50 a skos:Concept ;
#     skos:broader agrist:L ;
#     skos:prefLabel "Animal physiology and biochemistry"@en,
#         "Physiologie et biochimie animales"@fr .
#
# agrist:L51 a skos:Concept ;
#     skos:broader agrist:L ;
#     skos:prefLabel "Animal physiology - Nutrition"@en,
#         "Physiologie animale - Nutrition"@fr .
#
# agrist:L52 a skos:Concept ;
#     skos:broader agrist:L ;
#     skos:prefLabel "Animal Physiology - Growth and development"@en,
#         "Physiologie animale - Croissance et développement"@fr .
#
# agrist:L53 a skos:Concept ;
#     skos:broader agrist:L ;
#     skos:prefLabel "Animal physiology - Reproduction"@en,
#         "Physiologie animale - Reproduction"@fr .
#
# agrist:L60 a skos:Concept ;
#     skos:broader agrist:L ;
#     skos:prefLabel "Animal taxonomy and geography"@en,
#         "Taxonomie et géographie animales"@fr .
#
# agrist:L70 a skos:Concept ;
#     skos:broader agrist:L ;
#     skos:prefLabel "Veterinary science and hygiene - General aspects"@en,
#         "Sciences et hygiène vétérinaires - Considérations générales"@fr .
#
# agrist:L72 a skos:Concept ;
#     skos:broader agrist:L ;
#     skos:prefLabel "Pests of animals"@en,
#         "Organismes nuisibles des animaux"@fr .
#
# agrist:L73 a skos:Concept ;
#     skos:broader agrist:L ;
#     skos:prefLabel "Animal diseases"@en,
#         "Maladies des animaux"@fr .
#
# agrist:L74 a skos:Concept ;
#     skos:broader agrist:L ;
#     skos:prefLabel "Miscellaneous animal disorders"@en,
#         "Troubles divers des animaux"@fr .
#
# agrist:L75 a skos:Concept ;
#     skos:broader agrist:L ;
#     skos:prefLabel "Pharmacology and Toxicology"@en,
#         "Pharmacologie et toxicologie"@fr .
#
# agrist:M01 a skos:Concept ;
#     skos:broader agrist:M ;
#     skos:prefLabel "Fisheries and aquaculture - General aspects"@en,
#         "Pêche et aquaculture - Considérations générales"@fr .
#
# agrist:M11 a skos:Concept ;
#     skos:broader agrist:M ;
#     skos:prefLabel "Fisheries production"@en,
#         "Production de la pêche"@fr .
#
# agrist:M12 a skos:Concept ;
#     skos:broader agrist:M ;
#     skos:prefLabel "Aquaculture production"@en,
#         "Production de l'aquaculture"@fr .
#
# agrist:M40 a skos:Concept ;
#     skos:broader agrist:M ;
#     skos:prefLabel "Aquatic ecology"@en,
#         "Écologie aquatique"@fr .
#
# agrist:N01 a skos:Concept ;
#     skos:broader agrist:N ;
#     skos:prefLabel "Agricultural engineering"@en,
#         "Génie rural"@fr .
#
# agrist:N02 a skos:Concept ;
#     skos:broader agrist:N ;
#     skos:prefLabel "Farm layout"@en,
#         "Aménagement de l'exploitation agricole"@fr .
#
# agrist:N10 a skos:Concept ;
#     skos:broader agrist:N ;
#     skos:prefLabel "Agricultural structures"@en,
#         "Bâtiments agricoles"@fr .
#
# agrist:N20 a skos:Concept ;
#     skos:broader agrist:N ;
#     skos:prefLabel "Agricultural machinery and equipment"@en,
#         "Machines et matériels agricoles"@fr .
#
# agrist:P01 a skos:Concept ;
#     skos:broader agrist:P ;
#     skos:prefLabel "Nature conservation and land resources"@en,
#         "Conservation de la nature et ressources foncières"@fr .
#
# agrist:P02 a skos:Concept ;
#     skos:broader agrist:P ;
#     skos:prefLabel "Pollution"@en,
#         "Pollution"@fr .
#
# agrist:P05 a skos:Concept ;
#     skos:broader agrist:P ;
#     skos:prefLabel "Energy resources management"@en,
#         "Ressources énergétiques et leur gestion"@fr .
#
# agrist:P06 a skos:Concept ;
#     skos:broader agrist:P ;
#     skos:prefLabel "Renewable energy resources"@en,
#         "Sources d'énergie renouvelable"@fr .
#
# agrist:P07 a skos:Concept ;
#     skos:broader agrist:P ;
#     skos:prefLabel "Non-renewable energy resources"@en,
#         "Sources d'énergie non-renouvelable"@fr .
#
# agrist:P10 a skos:Concept ;
#     skos:broader agrist:P ;
#     skos:prefLabel "Water resources and management"@en,
#         "Ressources en eau et leur gestion"@fr .
#
# agrist:P11 a skos:Concept ;
#     skos:broader agrist:P ;
#     skos:prefLabel "Drainage"@en,
#         "Drainage"@fr .
#
# agrist:P30 a skos:Concept ;
#     skos:broader agrist:P ;
#     skos:prefLabel "Soil science and management"@en,
#         "Sciences et aménagement du sol"@fr .
#
# agrist:P31 a skos:Concept ;
#     skos:broader agrist:P ;
#     skos:prefLabel "Soil surveys and mapping"@en,
#         "Levés et cartographie des sols"@fr .
#
# agrist:P32 a skos:Concept ;
#     skos:broader agrist:P ;
#     skos:prefLabel "Soil classification and genesis"@en,
#         "Classification des sols et pédogenèse"@fr .
#
# agrist:P33 a skos:Concept ;
#     skos:broader agrist:P ;
#     skos:prefLabel "Soil chemistry and physics"@en,
#         "Chimie et physique du sol"@fr .
#
# agrist:P34 a skos:Concept ;
#     skos:broader agrist:P ;
#     skos:prefLabel "Soil biology"@en,
#         "Biologie du sol"@fr .
#
# agrist:P35 a skos:Concept ;
#     skos:broader agrist:P ;
#     skos:prefLabel "Soil fertility"@en,
#         "Fertilité du sol"@fr .
#
# agrist:P36 a skos:Concept ;
#     skos:broader agrist:P ;
#     skos:prefLabel "Soil erosion, conservation and reclamation"@en,
#         "Érosion, conservation et récupération des sols"@fr .
#
# agrist:P40 a skos:Concept ;
#     skos:broader agrist:P ;
#     skos:prefLabel "Meteorology and climatology"@en,
#         "Météorologie et climatologie"@fr .
#
# agrist:Q01 a skos:Concept ;
#     skos:broader agrist:Q ;
#     skos:prefLabel "Food science and technology - General aspects"@en,
#         "Sciences et technologie alimentaires - Considérations générales"@fr .
#
# agrist:Q02 a skos:Concept ;
#     skos:broader agrist:Q ;
#     skos:prefLabel "Food processing and preservation"@en,
#         "Traitement et conservation des produits alimentaires"@fr .
#
# agrist:Q03 a skos:Concept ;
#     skos:broader agrist:Q ;
#     skos:prefLabel "Food contamination"@en,
#         "Contamination et toxicologie alimentaires"@fr .
#
# agrist:Q04 a skos:Concept ;
#     skos:broader agrist:Q ;
#     skos:prefLabel "Food composition"@en,
#         "Composition des produits alimentaires"@fr .
#
# agrist:Q05 a skos:Concept ;
#     skos:broader agrist:Q ;
#     skos:prefLabel "Food additives"@en,
#         "Additifs alimentaires"@fr .
#
# agrist:Q51 a skos:Concept ;
#     skos:broader agrist:Q ;
#     skos:prefLabel "Feed technology"@en,
#         "Technologie des aliments pour animaux"@fr .
#
# agrist:Q52 a skos:Concept ;
#     skos:broader agrist:Q ;
#     skos:prefLabel "Feed processing and preservation"@en,
#         "Traitement et conservation des aliments pour animaux"@fr .
#
# agrist:Q53 a skos:Concept ;
#     skos:broader agrist:Q ;
#     skos:prefLabel "Feed contamination and toxicology"@en,
#         "Contamination et toxicologie des aliments pour animaux"@fr .
#
# agrist:Q54 a skos:Concept ;
#     skos:broader agrist:Q ;
#     skos:prefLabel "Feed composition"@en,
#         "Composition des aliments pour animaux"@fr .
#
# agrist:Q55 a skos:Concept ;
#     skos:broader agrist:Q ;
#     skos:prefLabel "Feed additives"@en,
#         "Additifs aux aliments des animaux"@fr .
#
# agrist:Q60 a skos:Concept ;
#     skos:broader agrist:Q ;
#     skos:prefLabel "Processing of non-food or non-feed agricultural products"@en,
#         "Traitement des produits agricoles non alimentaires"@fr .
#
# agrist:Q70 a skos:Concept ;
#     skos:broader agrist:Q ;
#     skos:prefLabel "Processing of agricultural wastes"@en,
#         "Traitement des déchets agricoles"@fr .
#
# agrist:Q80 a skos:Concept ;
#     skos:broader agrist:Q ;
#     skos:prefLabel "Packaging"@en,
#         "Conditionnement"@fr .
#
# agrist:S01 a skos:Concept ;
#     skos:broader agrist:S ;
#     skos:prefLabel "Human nutrition - General aspects"@en,
#         "Nutrition humaine - Considérations générales"@fr .
#
# agrist:S20 a skos:Concept ;
#     skos:broader agrist:S ;
#     skos:prefLabel "Physiology of human nutrition"@en,
#         "Physiologie de la nutrition humaine"@fr .
#
# agrist:S30 a skos:Concept ;
#     skos:broader agrist:S ;
#     skos:prefLabel "Diet and diet-related diseases"@en,
#         "Régimes alimentaires et maladies nutritionnelles"@fr .
#
# agrist:S40 a skos:Concept ;
#     skos:broader agrist:S ;
#     skos:prefLabel "Nutrition programmes"@en,
#         "Programmes alimentaires"@fr .
#
# agrist:S50 a skos:Concept ;
#     skos:broader agrist:S ;
#     skos:prefLabel "Human health"@en,
#         "Santé humaine"@fr .
#
# agrist:U01 a skos:Concept ;
#     skos:broader agrist:U ;
#     skos:prefLabel "Scientific and applied research - General aspects"@en,
#         "Recherche scientifique et technique - Considérations générales"@fr .
#
# agrist:U10 a skos:Concept ;
#     skos:broader agrist:U ;
#     skos:prefLabel "Computer science, mathematics and statistics"@en,
#         "Informatique, mathématiques et statistiques"@fr .
#
# agrist:U30 a skos:Concept ;
#     skos:broader agrist:U ;
#     skos:prefLabel "Research methods"@en,
#         "Méthodes et techniques de recherche"@fr .
#
# agrist:U50 a skos:Concept ;
#     skos:broader agrist:U ;
#     skos:prefLabel "Physical and chemical sciences"@en,
#         "Sciences physiques et chimie"@fr .
#
# agrist:U60 a skos:Concept ;
#     skos:broader agrist:U ;
#     skos:prefLabel "Life and Earth sciences"@en,
#         "Sciences de la vie et de la Terre"@fr .
#
# agrist:U70 a skos:Concept ;
#     skos:broader agrist:U ;
#     skos:prefLabel "Social sciences, economics and humanities"@en,
#         "Sciences humaines et sociales"@fr .

# %% [markdown]
# #### add scopeNotes

# %%
for ind, row in agrist_df.iterrows():
    
    sub_category = URIRef(agrist_ns + row['sub-category'])
    scope_note   = Literal(row['scopeNote'], lang='fr')
    editorial_note = Literal(row['editorialNote'], lang='fr')
    
    g.add( (sub_category , SKOS.scopeNote,  scope_note))
    g.add( (sub_category , SKOS.editorialNote,  editorial_note))

# %% [markdown]
# #### add seeAlso

# %%
agrist_df['editorialNotes'] = agrist_df['editorialNote'].apply(lambda x: x.split('\n'))

agrist_df = agrist_df.explode('editorialNotes')

# %%
sub_categories_codes = sorted(agrist_df['sub-category'].unique())
categories_codes = sorted(agrist_df['sub-category'].apply(lambda x: x[0]).unique())

def expand_range(codes):
    code_range = codes.split('-')
    expanded_range = [sub_categories_codes[x] for x  in range(sub_categories_codes.index(code_range[0]),
                                                              sub_categories_codes.index(code_range[1])+1) ]

    return expanded_range

def range_is_category(code_range):
    category = code_range[0][0]
    category_range = [x for x in sub_categories_codes if x.startswith(category)]
    if len(code_range) == len(category_range):
        return category
    return code_range

def expand_codes(codes):
    if '-' in codes:
        return range_is_category(expand_range(codes))
    elif ',' in codes:
        return list(map(str.strip, codes.split(',')))
    elif 'les codes' in codes:
        return re.findall(r'\b[A-Z]\b', codes)
    return [codes]

def validate_code(code):
    return code if code in sub_categories_codes + categories_codes else ''

# %%
s = 'les codes E'
re.findall(r'\b[A-Z]\b', s)
# Out:
# ['E']

# %%
agrist_df['seeAlso'] = agrist_df['editorialNotes'].apply(lambda x: x.split(' voir ')[-1].strip() ) 
agrist_df['seeAlso'] = agrist_df['seeAlso'].apply(expand_codes) 

agrist_df = agrist_df.explode('seeAlso')
agrist_df['seeAlso'] = agrist_df['seeAlso'].apply(validate_code)

# %%
agrist_df.tail()
# Out:
#     category       category-label-fr       category-label-en sub-category  \
# 134        U  SCIENCES ET TECHNIQUES  SCIENCE AND TECHNOLOGY          U60
# 134        U  SCIENCES ET TECHNIQUES  SCIENCE AND TECHNOLOGY          U60
# 135        U  SCIENCES ET TECHNIQUES  SCIENCE AND TECHNOLOGY          U70
# 135        U  SCIENCES ET TECHNIQUES  SCIENCE AND TECHNOLOGY          U70
# 135        U  SCIENCES ET TECHNIQUES  SCIENCE AND TECHNOLOGY          U70
#
#                  sub-category-label-fr  \
# 134  Sciences de la vie et de la Terre
# 134  Sciences de la vie et de la Terre
# 135      Sciences humaines et sociales
# 135      Sciences humaines et sociales
# 135      Sciences humaines et sociales
#
#                          sub-category-label-en  \
# 134                    Life and Earth sciences
# 134                    Life and Earth sciences
# 135  Social sciences, economics and humanities
# 135  Social sciences, economics and humanities
# 135  Social sciences, economics and humanities
#
#                                              scopeNote  \
# 134  Concerne les sciences biologiques fondamentale...
# 134  Concerne les sciences biologiques fondamentale...
# 135  Sciences sociales : psychologie ; économie et ...
# 135  Sciences sociales : psychologie ; économie et ...
# 135  Sciences sociales : psychologie ; économie et ...
#
#                                          editorialNote  \
# 134  écologie des animaux utiles, voir L20\ntélédét...
# 134  écologie des animaux utiles, voir L20\ntélédét...
# 135  droit agricole, voir D50\ndocumentation, bibli...
# 135  droit agricole, voir D50\ndocumentation, bibli...
# 135  droit agricole, voir D50\ndocumentation, bibli...
#
#                                         editorialNotes seeAlso
# 134      télédétection, photo-interprétation, voir U30     U30
# 134  météorologie et climatologie (agrométéorologie...     P40
# 135                           droit agricole, voir D50     D50
# 135  documentation, bibliothéconomie et sciences de...     C30
# 135  économie agricole, développement et sociologie...       E

# %%
for ind, row in agrist_df.iterrows():

    if row['seeAlso']:
        sub_category = URIRef(agrist_ns + row['sub-category'])
        see_also     = URIRef(agrist_ns + row['seeAlso'])

        g.add( (sub_category , RDFS.seeAlso, see_also ))

# %%
print(g.serialize(format='turtle').decode("utf-8"))
# Out:
# @prefix agrist: <http://dist.cirad.fr/agrist-thema/> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix skos: <http://www.w3.org/2004/02/skos/core#> .
#
# agrist:A01 a skos:Concept ;
#     skos:broader agrist:A ;
#     skos:editorialNote ""@fr ;
#     skos:prefLabel "Agriculture - General aspects"@en,
#         "Agriculture - Considérations générales"@fr ;
#     skos:scopeNote "Considérations sur l'agriculture dans son sens large"@fr .
#
# agrist:B10 a skos:Concept ;
#     rdfs:seeAlso agrist:F70,
#         agrist:K10,
#         agrist:L60,
#         agrist:P10,
#         agrist:P31,
#         agrist:P40 ;
#     skos:broader agrist:B ;
#     skos:editorialNote """cartographie climatique et cartographie météorologique, voir P40
# cartographie des eaux, voir P10
# cartographie des sols, voir P31
# cartographie forestière, voir K10
# distribution géographique des animaux, voir L60
# distribution géographique des plantes, voir F70"""@fr ;
#     skos:prefLabel "Geography"@en,
#         "Géographie"@fr ;
#     skos:scopeNote """Géographie physique relative à l'agriculture ou à la foresterie
# Géographie humaine
# Livres de géographie, cartes, atlas, voyages relatifs à l'agriculture"""@fr .
#
# agrist:B50 a skos:Concept ;
#     skos:broader agrist:B ;
#     skos:editorialNote ""@fr ;
#     skos:prefLabel "History"@en,
#         "Histoire"@fr ;
#     skos:scopeNote """Histoire de l'agriculture, archéologie appliquée à l'agriculture
# Biographies dans le domaine de l'agriculture"""@fr .
#
# agrist:D10 a skos:Concept ;
#     rdfs:seeAlso agrist:A50,
#         agrist:C10,
#         agrist:E10,
#         agrist:E12,
#         agrist:E14,
#         agrist:E20,
#         agrist:E50 ;
#     skos:broader agrist:D ;
#     skos:editorialNote """administration de l'économie, voir E10
# administration de l'enseignement, voir C10
# administration de l'exploitation agricole, voir E20
# administration de la recherche, voir A50
# administration de la santé, voir E50
# administration des affaires sociales, voir E50
# administration du travail, voir E12
# objectifs, politiques, programmes de développement, voir E14"""@fr ;
#     skos:prefLabel "Public administration"@en,
#         "Administration publique"@fr ;
#     skos:scopeNote """Administration publique de l'agriculture en général
# Cadre institutionnel des structures agricoles chargées de fonctions gouvernementales"""@fr .
#
# agrist:L75 a skos:Concept ;
#     skos:broader agrist:L ;
#     skos:editorialNote ""@fr ;
#     skos:prefLabel "Pharmacology and Toxicology"@en,
#         "Pharmacologie et toxicologie"@fr ;
#     skos:scopeNote """Utilisation de médicaments en médecine vétérinaire (de la pharmacothérapie), principalement chez les animaux domestiques
# Classe de médicaments et indication de traitement
# Comprend également la pharmacopée traditionnelle
# Traite aussi de la toxicologie vétérinaire : identification des toxines et traitement des toxicoses"""@fr .
#
# agrist:U01 a skos:Concept ;
#     rdfs:seeAlso agrist:A50 ;
#     skos:broader agrist:U ;
#     skos:editorialNote "recherche agronomique, voir A50"@fr ;
#     skos:prefLabel "Scientific and applied research - General aspects"@en,
#         "Recherche scientifique et technique - Considérations générales"@fr ;
#     skos:scopeNote "La recherche scientifique en général : plans, politiques, programmes et projets de recherche, administration et financement de la recherche, science ouverte, éthique, etc."@fr .
#
# agrist:U10 a skos:Concept ;
#     rdfs:seeAlso agrist:E10,
#         agrist:E70,
#         agrist:K10 ;
#     skos:broader agrist:U ;
#     skos:editorialNote """économétrie en général, modèles économiques, voir E10
# modèles économétriques de marché, voir E70
# modèles informatiques de peuplements forestiers, voir K10"""@fr ;
#     skos:prefLabel "Computer science, mathematics and statistics"@en,
#         "Informatique, mathématiques et statistiques"@fr ;
#     skos:scopeNote """Concerne les différentes disciplines de l'informatique, des mathématiques et des statistiques
# Modélisation, programmation, informatique"""@fr .
#
# agrist:U50 a skos:Concept ;
#     rdfs:seeAlso agrist:U30,
#         agrist:U60 ;
#     skos:broader agrist:U ;
#     skos:editorialNote """biochimie, voir U60
# télédétection, voir U30"""@fr ;
#     skos:prefLabel "Physical and chemical sciences"@en,
#         "Sciences physiques et chimie"@fr ;
#     skos:scopeNote """Concerne les différentes disciplines de la physique et de la chimie et les technologies associées sauf agricoles
# Physique : électromagnétisme, optique, acoustique, thermodynamique, mécanique des solides, mécanique des fluides, physiques classique et quantique, relativité générale et gravitation.
# Chimie : chimie générale et chimie physique, chimie minérale, chimie organique, chimie analytique, génie chimique, physico-chimie des polymères
# Technologies associées : électronique, télécommunications, énergie, métaux, métallurgie, génie mécanique, construction mécanique"""@fr .
#
# agrist:C30 a skos:Concept ;
#     rdfs:seeAlso agrist:C20 ;
#     skos:broader agrist:C ;
#     skos:editorialNote "communication, médias de masse, journalisme agricole, voir C20"@fr ;
#     skos:prefLabel "Documentation and information"@en,
#         "Documentation et information"@fr ;
#     skos:scopeNote """Documentation, bibliothéconomie et sciences de l'information relatives à l'agriculture
# Compilation, codage et diffusion de l'information
# Services d'information, activités des bibliothèques
# Bibliographies, glossaires, etc.
# Bases de données comme éléments des systèmes d'information
# Pour fouille de texte, data mining, terminologie, intelligence artificielle, Web sémantique, ontologies, traitement du langage, Big data, réseaux sociaux, etc., ajouter U10"""@fr .
#
# agrist:H01 a skos:Concept ;
#     rdfs:seeAlso agrist:D50,
#         agrist:H02,
#         agrist:H10,
#         agrist:H20,
#         agrist:H60,
#         agrist:J11,
#         agrist:J12,
#         agrist:L72,
#         agrist:L73,
#         agrist:L74,
#         agrist:P02,
#         agrist:Q03,
#         agrist:Q53,
#         agrist:S50 ;
#     skos:broader agrist:H ;
#     skos:editorialNote """conservation des produits d'origine végétale, voir J11
# dégâts causés au milieu par les pesticides, voir P02
# effets phytotoxiques des pesticides, voir H02
# élevage d'organismes utilisés dans la lutte contre les bioagresseurs, voir H10, H20, L72, L73
# maladies des plantes, voir H20
# mauvaises herbes et désherbage, voir H60
# préservation du bois, voir J12
# ravageurs des plantes, voir H10
# réglementation relative aux résidus toxiques, voir D50
# résidus de pesticides dans l'air, le sol, l'eau, voir P02
# résidus de pesticides dans les aliments pour animaux, voir Q53
# résidus de pesticides dans les produits alimentaires, voir Q03
# toxicité des pesticides pour l'être humain, voir S50
# toxicité des pesticides pour les animaux utiles, voir L74
# toxicité des pesticides pour les plantes utiles, voir H02"""@fr ;
#     skos:prefLabel "Protection of plants - General aspects"@en,
#         "Protection des végétaux - Considérations générales"@fr ;
#     skos:scopeNote """Considérations générales sur les facteurs nuisibles (bioagresseurs) aux plantes utiles (y compris les arbres forestiers et les plantes aquatiques), mesures et moyens de lutte ou de protection
# Services et organismes de protection des végétaux"""@fr .
#
# agrist:L40 a skos:Concept ;
#     rdfs:seeAlso agrist:H10,
#         agrist:H20,
#         agrist:L50,
#         agrist:L51,
#         agrist:L52,
#         agrist:L53,
#         agrist:L72,
#         agrist:L73 ;
#     skos:broader agrist:L ;
#     skos:editorialNote """anatomie et morphologie des organismes nuisibles, voir H10, L72
# anatomie et morphologie des organismes utilisés dans la lutte contre les organismes nuisibles et les maladies, voir H10, H20, L72, L73
# métamorphose des animaux, voir L52
# physiologie animale, voir L50-L53"""@fr ;
#     skos:prefLabel "Animal structure"@en,
#         "Anatomie et morphologie des animaux"@fr ;
#     skos:scopeNote "Anatomie, cytologie, histologie, ultrastructure et morphologie des animaux utiles aquatiques et terrestres (à l'exclusion des organismes utilisés dans la lutte contre les organismes nuisibles et les maladies)"@fr .
#
# agrist:N02 a skos:Concept ;
#     rdfs:seeAlso agrist:N01,
#         agrist:N10 ;
#     skos:broader agrist:N ;
#     skos:editorialNote """bâtiments agricoles, voir N10
# génie rural, voir N01"""@fr ;
#     skos:prefLabel "Farm layout"@en,
#         "Aménagement de l'exploitation agricole"@fr ;
#     skos:scopeNote "Aménagement de l'exploitation agricole : tracé de routes, de chemins, emplacement de bâtiments, sites de travail, parcellaire, réseau de drainage de l'exploitation"@fr .
#
# agrist:Q01 a skos:Concept ;
#     rdfs:seeAlso agrist:E70,
#         agrist:Q02,
#         agrist:Q51,
#         agrist:Q52,
#         agrist:Q60,
#         agrist:Q70,
#         agrist:Q80,
#         agrist:S01,
#         agrist:S20,
#         agrist:S30,
#         agrist:S40 ;
#     skos:broader agrist:Q ;
#     skos:editorialNote """conditionnement, voir Q80
# étiquetage de contenu, normes, classement des produits agricoles, voir E70
# législation concernant le contrôle de la qualité des produits agricoles, voir E70
# nutrition humaine, voir S01-S40
# première transformation de produits agricoles non-alimentaires, voir Q60
# technologie des aliments pour animaux, voir Q51
# traitement des aliments pour animaux, voir Q52
# traitement des déchets agricoles, voir Q70
# traitement des produits alimentaires, voir Q02"""@fr ;
#     skos:prefLabel "Food science and technology - General aspects"@en,
#         "Sciences et technologie alimentaires - Considérations générales"@fr ;
#     skos:scopeNote "Sciences des aliments et technologie alimentaire en général"@fr .
#
# agrist:U60 a skos:Concept ;
#     rdfs:seeAlso agrist:L20,
#         agrist:P40,
#         agrist:U30 ;
#     skos:broader agrist:U ;
#     skos:editorialNote """écologie des animaux utiles, voir L20
# télédétection, photo-interprétation, voir U30
# météorologie et climatologie (agrométéorologie), voir P40"""@fr ;
#     skos:prefLabel "Life and Earth sciences"@en,
#         "Sciences de la vie et de la Terre"@fr ;
#     skos:scopeNote """Concerne les sciences biologiques fondamentales et appliquées, sauf les sciences et applications agricoles
# Biologie et sciences associées : biologie moléculaire et cellulaire ; microbiologie ; immunologie fondamentale ; génétique ; évolution biologique et moléculaire ; cytologie, morphologie, systématique, floristique et évolution des végétaux ; physiologie végétale et développement, éthologie animale ; écologie animale, végétale et microbienne ; embryologie : invertébrés et vertébrés ; tératologie. Biochimie analytique, structurale et métabolique. Biophysique moléculaire ; biophysique des tissus, organes et organismes. Biotechnologie
# Sciences de la terre : géologie ; minéralogie géochimie ; tectonique des plaques ; hydrologie ; stratigraphie ; paléontologie. Géophysique externe ; géodésie et gravimétrie ; physique des océans ; neiges, glaces, glaciers. Astronomie, astrophysique"""@fr .
#
# agrist:U70 a skos:Concept ;
#     rdfs:seeAlso agrist:C30,
#         agrist:D50,
#         agrist:E ;
#     skos:broader agrist:U ;
#     skos:editorialNote """droit agricole, voir D50
# documentation, bibliothéconomie et sciences de l'information relatives à l'agriculture, voir C30
# économie agricole, développement et sociologie rurale, voir les codes E"""@fr ;
#     skos:prefLabel "Social sciences, economics and humanities"@en,
#         "Sciences humaines et sociales"@fr ;
#     skos:scopeNote """Sciences sociales : psychologie ; économie et gestion (économie, économétrie, relations industrielles, administration et gestion des entreprises) ; sciences de l'éducation (éducation en général, pédagogie, didactique) ; sociologie (sociologie, démographie, anthropologie, ethnologie, études sur les familles) ; droit (droit, criminologie, pénologie) ; science politique (sciences politiques, gestion publique, théorie de l'organisation) ; géographie sociale et économique : science de l'environnement (aspects sociaux), géographie culturelle et économique, études d'urbanisme (aménagement et développement urbains) : planification des transports et aspects sociaux des transports ; médias et communication (journalisme, science de l'information (aspects sociaux), bibliothéconomie, médias et communication socioculturelle).
# Sciences humaines (ou humanités) : histoire, histoire de l'art, archéologie ; langues et littérature (études générales de langue, langues particulières, études de littérature générale, théorie littéraire, littératures particulières, linguistique) ; philosophie, morale et religion (philosophie, histoire et philosophie des sciences et de la technologie, éthique, théologie, études religieuses) ; arts (arts, conception architecturale, études des arts de la scène (musicologie, science théâtrale, dramaturgie), études du folklore, études portant sur les films, la radio et la télévision)"""@fr .
#
# agrist:E40 a skos:Concept ;
#     rdfs:seeAlso agrist:E13,
#         agrist:E16,
#         agrist:E20,
#         agrist:E50,
#         agrist:E70 ;
#     skos:broader agrist:E ;
#     skos:editorialNote """coopératives de crédit, voir E13
# entreprises agricoles, voir E20
# évaluation économique des coopératives de commercialisation, voir E70
# économie de l'organisation et de la gestion coopératives des exploitations agricoles, voir E20
# organisation des coopératives pour l'habitat rural, voir E50
# économie de la production dans une entreprise coopérative, voir E16
# évaluation économique des coopératives de commercialisation, voir E70
# économie de l'organisation et de la gestion coopératives des exploitations agricoles, voir E20
# organisation des coopératives pour l'habitat rural, voir E50
# économie de la production dans une entreprise coopérative, voir E16"""@fr ;
#     skos:prefLabel "Cooperatives"@en,
#         "Coopératives"@fr ;
#     skos:scopeNote """Considérations générales sur les coopératives agricoles et les organisations paysannes
# Incidence des coopératives sur l'économie agricole"""@fr .
#
# agrist:F50 a skos:Concept ;
#     rdfs:seeAlso agrist:F60,
#         agrist:F61,
#         agrist:F62,
#         agrist:F63,
#         agrist:H10,
#         agrist:H20,
#         agrist:H60,
#         agrist:L72,
#         agrist:L73 ;
#     skos:broader agrist:F ;
#     skos:editorialNote """anatomie et morphologie des mauvaises herbes, voir H60
# anatomie et morphologie des organismes utilisés dans la lutte contre les bioagresseurs, voir H10, H20, L72, L73
# physiologie végétale, voir F60-F63"""@fr ;
#     skos:prefLabel "Plant structure"@en,
#         "Anatomie et morphologie des plantes"@fr ;
#     skos:scopeNote """Anatomie, cytologie, histologie, ultrastructure et morphologie des plantes utiles (y compris les arbres forestiers et les plantes aquatiques)
# Structure du bois
# Port de la plante : aspect général d'une plante"""@fr .
#
# agrist:F60 a skos:Concept ;
#     rdfs:seeAlso agrist:F01,
#         agrist:F04,
#         agrist:F06,
#         agrist:F40,
#         agrist:F61,
#         agrist:F62,
#         agrist:F63,
#         agrist:H10,
#         agrist:H20,
#         agrist:H50,
#         agrist:H60,
#         agrist:L72,
#         agrist:L73 ;
#     skos:broader agrist:F ;
#     skos:editorialNote """croissance et développement physiologique des plantes, voir F62
# effet du milieu sur les processus biologiques chez les plantes, voir F40
# immunité : résistance des plantes aux maladies, voir H20
# immunité : résistance des plantes aux bioagresseurs, voir H10
# métabolisme relatif à la nutrition, voir F61
# physiologie de la nutrition végétale, voir F61
# physiologie de la reproduction végétale, voir F63
# physiologie des mauvaises herbes, voir H60
# physiologie et biochimie des organismes utilisés dans la lutte contre les bioagresseurs, voir H10, H20, L72, L73
# réponse de la plante à l'irrigation, voir F06
# réponse de la plante aux engrais, voir F04
# réponse de la plante aux techniques culturales, voir F01
# rusticité des plantes, résistance aux conditions extrêmes, voir H50
# troubles physiologiques des plantes, voir H50"""@fr ;
#     skos:prefLabel "Plant physiology and biochemistry"@en,
#         "Physiologie et biochimie végétale"@fr ;
#     skos:scopeNote """Ne comprend pas les documents dans lesquels les plantes sont traitées comme des organismes d'expérimentation pour la recherche fondamentale en physiologie et en biochimie
# Aspects généraux de la physiologie et de la biochimie des plantes utiles (y compris les arbres forestiers et les plantes aquatiques) : circulation et émission de liquides et de gaz, relation plante-eau, exsudation, transpiration, respiration, etc.
# Composition chimique et constituants des plantes utiles"""@fr .
#
# agrist:F70 a skos:Concept ;
#     rdfs:seeAlso agrist:F30,
#         agrist:F40,
#         agrist:H10,
#         agrist:H20,
#         agrist:H60,
#         agrist:L72,
#         agrist:L73,
#         agrist:M40,
#         agrist:P34 ;
#     skos:broader agrist:F ;
#     skos:editorialNote """collecte et introduction des plantes, voir F30
# écologie des plantes aquatiques, voir M40
# écologie des plantes terrestres, voir F40
# flore du sol, voir P34
# génétique végétale, voir F30
# taxonomie des mauvaises herbes, voir H60
# taxonomie des organismes utilisés dans la lutte contre les bioagresseurs, voir H10, H20, L72, L73
# variation des plantes, voir F30"""@fr ;
#     skos:prefLabel "Plant taxonomy and geography"@en,
#         "Taxonomie végétale et phytogéographie"@fr ;
#     skos:scopeNote """Classification, identification, nomenclature et phylogénie ou évolution des plantes utiles (y compris les arbres forestiers et les plantes aquatiques)
# Distribution géographique naturelle des plantes ; flore ; listes de référence des plantes"""@fr .
#
# agrist:K01 a skos:Concept ;
#     rdfs:seeAlso agrist:E12,
#         agrist:E20,
#         agrist:F40,
#         agrist:K10,
#         agrist:K11,
#         agrist:P01 ;
#     skos:broader agrist:K ;
#     skos:editorialNote """conservation de la biodiversité forestière, voir P01
# conservation des forêts utilisées pour les loisirs, voir P01
# conservation du milieu forestier, voir P01
# écologie forestière, voir F40
# génie forestier, voir K11
# géographie des forêts, répartition des forêts, influence de la forêt sur l'environnement, voir P01
# gestion forestière, voir E20
# production forestière, voir K10
# travail et emploi forestiers, voir E12
# utilisation de la forêt pour les loisirs, voir P01"""@fr ;
#     skos:prefLabel "Forestry - General aspects"@en,
#         "Foresterie - Considérations générales"@fr ;
#     skos:scopeNote """Considérations sur la forêt en général
# Influence des forêts : effets dus à la présence des forêts sur l'eau, le sol, le climat et la santé"""@fr .
#
# agrist:K11 a skos:Concept ;
#     rdfs:seeAlso agrist:J12,
#         agrist:N01,
#         agrist:N20 ;
#     skos:broader agrist:K ;
#     skos:editorialNote """matériels et équipements forestiers, voir N20
# routes rurales, voir N01
# transport des produits forestiers, voir J12"""@fr ;
#     skos:prefLabel "Forest engineering"@en,
#         "Génie forestier"@fr ;
#     skos:scopeNote """Génie forestier, défrichement, nivellement, stabilisation des pentes, etc.
# Routes forestières"""@fr .
#
# agrist:L50 a skos:Concept ;
#     rdfs:seeAlso agrist:H10,
#         agrist:H20,
#         agrist:L51,
#         agrist:L52,
#         agrist:L53,
#         agrist:L70,
#         agrist:L72,
#         agrist:L73,
#         agrist:L74 ;
#     skos:broader agrist:L ;
#     skos:editorialNote """immunité : résistance des animaux aux maladies, voir L73
# immunité : résistance des animaux aux organismes nuisibles, voir L72
# immunologie (en général), voir L70
# métamorphose, croissance et développement des animaux, voir L52
# physiologie de la nutrition animale, voir L51
# physiologie de la reproduction animale, voir L53
# physiologie des organismes nuisibles, voir H10, L72
# physiologie et biochimie des organismes utilisés dans la lutte contre les organismes nuisibles et les maladies, voir H10, H20, L72, L73
# résistance des animaux au climat, aux conditions extrêmes, voir L74"""@fr ;
#     skos:prefLabel "Animal physiology and biochemistry"@en,
#         "Physiologie et biochimie animales"@fr ;
#     skos:scopeNote """Ne comprend pas les documents dans lesquels les animaux sont traités comme matériel d'expérimentation pour la recherche fondamentale physiologique ou biochimique
# Aspects généraux de la physiologie et de la biochimie des animaux utiles aquatiques et terrestres (à l'exclusion des organismes utilisés dans la lutte contre les organismes nuisibles et les maladies) ; circulation, respiration, etc.
# Composition chimique, analyse chimique des animaux utiles (à l'exclusion des organismes utilisés dans la lutte contre les organismes nuisibles et les maladies)"""@fr .
#
# agrist:L60 a skos:Concept ;
#     rdfs:seeAlso agrist:H10,
#         agrist:H20,
#         agrist:L10,
#         agrist:L20,
#         agrist:L72,
#         agrist:L73,
#         agrist:M40,
#         agrist:P34 ;
#     skos:broader agrist:L ;
#     skos:editorialNote """écologie animale : aquatique, voir M40
# écologie animale : terrestre, voir L20
# faune du sol, voir P34
# génétique animale, voir L10
# taxonomie et distribution des organismes nuisibles, voir H10, L72
# taxonomie et distribution des organismes utilisés dans la lutte contre les organismes nuisibles et les maladies, voir H10, H20, L72, L73"""@fr ;
#     skos:prefLabel "Animal taxonomy and geography"@en,
#         "Taxonomie et géographie animales"@fr ;
#     skos:scopeNote """Classification, identification, nomenclature et phylogénie des animaux utiles aquatiques et terrestres (à l'exclusion des organismes utilisés dans la lutte contre les organismes nuisibles et les maladies)
# Répartition géographique des animaux ; faune"""@fr .
#
# agrist:P07 a skos:Concept ;
#     rdfs:seeAlso agrist:P05,
#         agrist:P06 ;
#     skos:broader agrist:P ;
#     skos:editorialNote """gestion des ressources énergétiques, voir P05
# sources d'énergie renouvelable, voir P06"""@fr ;
#     skos:prefLabel "Non-renewable energy resources"@en,
#         "Sources d'énergie non-renouvelable"@fr ;
#     skos:scopeNote "Développement de l'énergie utilisée pour la production agricole ou le traitement des produits après récolte à partir de sources d'énergie conventionnelle ou non-renouvelable (telles que pétrole, schistes bitumineux, gaz naturel, charbon, tourbe, etc.)"@fr .
#
# agrist:Q05 a skos:Concept ;
#     rdfs:seeAlso agrist:Q03,
#         agrist:Q04,
#         agrist:Q55 ;
#     skos:broader agrist:Q ;
#     skos:editorialNote """additifs aux aliments pour animaux, voir Q55
# composition des produits alimentaires, voir Q04
# santé publique et produits alimentaires, voir Q03"""@fr ;
#     skos:prefLabel "Food additives"@en,
#         "Additifs alimentaires"@fr ;
#     skos:scopeNote "Substances ajoutées aux produits alimentaires pour en améliorer la couleur, la flaveur, la texture ; assaisonnements, émulsifiants, stabilisants, édulcorants, etc."@fr .
#
# agrist:Q70 a skos:Concept ;
#     rdfs:seeAlso agrist:F04,
#         agrist:F06,
#         agrist:N01,
#         agrist:P02,
#         agrist:P06,
#         agrist:P10 ;
#     skos:broader agrist:Q ;
#     skos:editorialNote """pollution et polluants, voir P02
# production d'énergie a partir des déchets, voir P06
# système d'élimination des déchets et des eaux usées, voir N01
# traitement des eaux usées, voir P10
# utilisation des déchets pour la fertilisation, voir F04
# utilisation des eaux usées pour l'irrigation, voir F06"""@fr ;
#     skos:prefLabel "Processing of agricultural wastes"@en,
#         "Traitement des déchets agricoles"@fr ;
#     skos:scopeNote """Transformation des déchets et sous-produits agricoles (à l'exclusion du traitement des eaux usées et de la production d'énergie à partir des déchets)
# Gestion des déchets (à l'exclusion de la gestion des eaux usées): élimination des déchets, recyclage des déchets
# Traitement des déchets (à l'exclusion du traitement des eaux usées) : méthodes d'épuration, traitements physique et mécanique, traitement biologique, etc."""@fr .
#
# agrist:Q80 a skos:Concept ;
#     rdfs:seeAlso agrist:E80,
#         agrist:J10,
#         agrist:J11,
#         agrist:J12,
#         agrist:J13,
#         agrist:J14,
#         agrist:Q02,
#         agrist:Q52 ;
#     skos:broader agrist:Q ;
#     skos:editorialNote """conservation des aliments pour animaux, voir Q52
# conservation des produits alimentaires, voir Q02
# conservation des produits alimentaires à la maison, voir E80
# stockage des aliments pour animaux, voir J10-J14
# stockage des produits alimentaires, voir J10-J14"""@fr ;
#     skos:prefLabel "Packaging"@en,
#         "Conditionnement"@fr ;
#     skos:scopeNote """À utiliser pour l'emballage et le conditionnement des produits agricoles en général
# Conditionnement des produits agricoles : mise en boîte, embouteillage, emballage hermétique, emballage sous vide, empaquetage, enrobage, mise en balle, etc."""@fr .
#
# agrist:A50 a skos:Concept ;
#     rdfs:seeAlso agrist:C10,
#         agrist:E70,
#         agrist:U30 ;
#     skos:broader agrist:A ;
#     skos:editorialNote """méthodes et techniques de recherche, voir U30
# recherche de marché, voir E70
# stations et fermes expérimentales, voir C10"""@fr ;
#     skos:prefLabel "Agricultural research"@en,
#         "Recherche agronomique"@fr ;
#     skos:scopeNote """Administration de la recherche agronomique en général
# Plans, politiques, programmes et projets de recherche
# Administration et financement de la recherche
# Personnel de recherche"""@fr .
#
# agrist:F02 a skos:Concept ;
#     rdfs:seeAlso agrist:F01,
#         agrist:F03,
#         agrist:F30,
#         agrist:F63,
#         agrist:K10 ;
#     skos:broader agrist:F ;
#     skos:editorialNote """génétique et amélioration des plantes, voir F30
# multiplication des arbres forestiers, voir K10
# physiologie de la reproduction végétale, voir F63
# production et traitement des semences (à l'exclusion de la production et du traitement des semences forestières), voir F03
# production et traitement des semences forestières, voir K10
# semis, date de semis, profondeur de semis, densité de semis, voir F01"""@fr ;
#     skos:prefLabel "Plant propagation"@en,
#         "Multiplication végétative des plantes"@fr ;
#     skos:scopeNote """Techniques de multiplication végétative des plantes (à l'exclusion de la multiplication des arbres forestiers)
# Multiplication : greffage ; écussonnage ; culture de cellules et de méristèmes ; éclatement ; marcottage ; bouturage ; clonage, etc. (à l'exclusion de la multiplication des arbres forestiers par bouturage, clonage, etc.)"""@fr .
#
# agrist:L52 a skos:Concept ;
#     rdfs:seeAlso agrist:H10,
#         agrist:H20,
#         agrist:L72,
#         agrist:L73 ;
#     skos:broader agrist:L ;
#     skos:editorialNote """croissance et développement des organismes nuisibles, voir H10, L72
# croissance et développement des organismes utilisés dans la lutte contre les organismes nuisibles et les maladies, voir H10, H20, L72, L73"""@fr ;
#     skos:prefLabel "Animal Physiology - Growth and development"@en,
#         "Physiologie animale - Croissance et développement"@fr ;
#     skos:scopeNote "Croissance et développement des animaux utiles aquatiques et terrestres (à l'exclusion des organismes utilisés dans la lutte contre les organismes nuisibles et les maladies) ; métamorphose, sénescence animale, différenciation cellulaire, etc."@fr .
#
# agrist:M01 a skos:Concept ;
#     rdfs:seeAlso agrist:D50,
#         agrist:E20,
#         agrist:E21,
#         agrist:M11,
#         agrist:M12 ;
#     skos:broader agrist:M ;
#     skos:editorialNote """industrie aquacole, voir E21
# industrie de la pêche, voir E21
# organisation, administration et gestion des entreprises de pêche et d'aquaculture, voir E20
# production de l'aquaculture, voir M12
# production de la pêche, voir M11
# réglementation de la pêche, voir D50"""@fr ;
#     skos:prefLabel "Fisheries and aquaculture - General aspects"@en,
#         "Pêche et aquaculture - Considérations générales"@fr ;
#     skos:scopeNote """Ne comprend pas l'information sur les études scientifiques en océanographie et limnologie, sauf si elle a des relations spécifiques avec la pêche et l'aquaculture
# Considérations générales sur la pêche et l'aquaculture
# Exploration et amélioration des ressources aquatiques, végétales et animales, pour leur utilisation
# Conservation des ressources aquatiques en général"""@fr .
#
# agrist:N10 a skos:Concept ;
#     rdfs:seeAlso agrist:N20 ;
#     skos:broader agrist:N ;
#     skos:editorialNote "machines et matériels agricoles, voir N20"@fr ;
#     skos:prefLabel "Agricultural structures"@en,
#         "Bâtiments agricoles"@fr ;
#     skos:scopeNote "Conception, matériaux, construction et entretien des édifices agricoles tels que bâtiments de ferme ; logement des animaux ; abris pour plantes : serres, etc. ; bâtiments de stockage des produits agricoles : granges, silos, etc. ; bâtiments pour les produits de récolte et leur manutention ; bâtiments annexes : garages, hangars à matériel, etc. ; enclos et installations de protection ; etc."@fr .
#
# agrist:P30 a skos:Concept ;
#     rdfs:seeAlso agrist:E11,
#         agrist:F04,
#         agrist:F06,
#         agrist:F07,
#         agrist:P01,
#         agrist:P10,
#         agrist:P31,
#         agrist:P35,
#         agrist:P36 ;
#     skos:broader agrist:P ;
#     skos:editorialNote """économie de la mise en valeur du sol, voir E11
# érosion du sol, voir P36
# façon culturale, voir F07
# fertilisation, voir F04
# fertilité du sol, voir P35
# irrigation, voir F06
# levés pédologiques, voir P31
# paysagisme, conservation du paysage et de la nature, voir P01
# pertes de sol, conservation du sol, voir P36
# récupération du sol, voir P36
# ressources en eau et leur gestion, voir P10
# ressources foncières, voir P01"""@fr ;
#     skos:prefLabel "Soil science and management"@en,
#         "Sciences et aménagement du sol"@fr ;
#     skos:scopeNote """Sciences du sol en général
# Potentialités des ressources en sol ; capabilité du sol
# Planification des ressources en sols et leur amélioration"""@fr .
#
# agrist:P33 a skos:Concept ;
#     rdfs:seeAlso agrist:F06,
#         agrist:P11,
#         agrist:P31,
#         agrist:P32,
#         agrist:P34,
#         agrist:P35,
#         agrist:P36 ;
#     skos:broader agrist:P ;
#     skos:editorialNote """biochimie du sol, voir P34
# classification des sols, voir P32
# drainage, voir P11
# érosion du sol, voir P36
# fertilité du sol, voir P35
# irrigation, voir F06
# levés pédologiques, voir P31"""@fr ;
#     skos:prefLabel "Soil chemistry and physics"@en,
#         "Chimie et physique du sol"@fr ;
#     skos:scopeNote """Chimie du sol : chimie organique et minérale du sol (mais non la biochimie)
# Analyse du sol ; évaluation du sol ; techniques d'expérimentation, expérimentation en plein champ
# Physique du sol ; propriétés physiques : aération, texture, etc. ; teneur en eau du sol et capacité de rétention en eau du sol, solution du sol, perméabilité ; absorption et adsorption, capillarité, infiltration ; phénomènes électriques et autres aspects physiques en relation avec le sol
# Mécanique et structure du sol, y compris l'état structural et la stabilité, la porosité
# Génie des sols"""@fr .
#
# agrist:Q51 a skos:Concept ;
#     rdfs:seeAlso agrist:D50,
#         agrist:L02,
#         agrist:M12,
#         agrist:Q01,
#         agrist:Q52,
#         agrist:Q53 ;
#     skos:broader agrist:Q ;
#     skos:editorialNote """alimentation des animaux aquatiques, voir M12
# alimentation des animaux terrestres, voir L02
# contrôle sanitaire des aliments pour animaux, voir Q53
# législation concernant le contrôle de la qualité des aliments pour animaux, voir D50
# science et technologie alimentaires, voir Q01
# traitement des aliments pour animaux, voir Q52"""@fr ;
#     skos:prefLabel "Feed technology"@en,
#         "Technologie des aliments pour animaux"@fr ;
#     skos:scopeNote "Technologie des aliments pour animaux en général"@fr .
#
# agrist:Q55 a skos:Concept ;
#     rdfs:seeAlso agrist:L02,
#         agrist:M12,
#         agrist:Q05,
#         agrist:Q53,
#         agrist:Q54 ;
#     skos:broader agrist:Q ;
#     skos:editorialNote """additifs alimentaires (pour l'être humain), voir Q05
# alimentation des animaux aquatiques, voir M12
# alimentation des animaux terrestres, voir L02
# composition des aliments pour animaux, voir Q54
# inspection, contrôle sanitaire des aliments pour animaux, voir Q53"""@fr ;
#     skos:prefLabel "Feed additives"@en,
#         "Additifs aux aliments des animaux"@fr ;
#     skos:scopeNote "Additifs alimentaires pour animaux : substances ajoutées aux aliments ou concentrés pour animaux destinés à équilibrer les rations du bétail et améliorer la croissance des animaux"@fr .
#
# agrist:C20 a skos:Concept ;
#     rdfs:seeAlso agrist:C10,
#         agrist:E73 ;
#     skos:broader agrist:C ;
#     skos:editorialNote """éducation et protection du consommateur, voir E73
# enseignement professionnel, voir C10
# planification de l'éducation, méthodes d'enseignement et de formation professionnelle, voir C10"""@fr ;
#     skos:prefLabel "Extension"@en,
#         "Vulgarisation"@fr ;
#     skos:scopeNote """Vulgarisation, assistance-conseil et démonstrations en agriculture
# Vulgarisation agricole comprenant la communication systématique et organisée avec les exploitants agricoles en vue de les aider à choisir les objectifs réalisables, acquérir les connaissances et techniques nécessaires, identifier leurs problèmes, formuler des solutions, résoudre les problèmes identifiés et évaluer les résultats obtenus
# Opérations et services de vulgarisation, comprenant la planification des programmes, l'organisation, la gestion et l'évaluation des services de vulgarisation, méthodes de communication, conseils et directives aux exploitants agricoles et aux ruraux, démonstrations
# Agents de vulgarisation
# Communication, développement et utilisation des médias de masse (tels que journaux, émissions de radio ou de télévision, films) destinés à la population rurale ; journalisme agricole"""@fr .
#
# agrist:E71 a skos:Concept ;
#     rdfs:seeAlso agrist:D50,
#         agrist:E72 ;
#     skos:broader agrist:E ;
#     skos:editorialNote """commerce intérieur, voir E72
# droit du commerce international, voir D50
# réglementation des importations et des exportations, voir D50
# réglementation douanière, voir D50"""@fr ;
#     skos:prefLabel "International trade"@en,
#         "Commerce international"@fr ;
#     skos:scopeNote """Commerce international relatif aux produits agricoles de base ou aux produits utilisés pour la production agricole, et aux politiques concernant ce domaine, y compris les mesures pour le développement du commerce, les barrières douanières, le contrôle des importations, les politiques tarifaires
# Conditions du marché mondial
# Accords de commerce international, marchés communs, politiques agricoles communes, règles communes de conduite en matière de commerce international et de relations commerciales ; accords multinationaux qui peuvent comprendre des objectifs tels que l'accroissement de la productivité agricole, la stabilisation des marchés agricoles, des prix communautaires garantis pour les produits agricoles, le commerce sans restriction entre pays membres, les relations de systèmes de marché commun avec des pays non membres, etc."""@fr .
#
# agrist:E72 a skos:Concept ;
#     rdfs:seeAlso agrist:E70,
#         agrist:E71,
#         agrist:E73 ;
#     skos:broader agrist:E ;
#     skos:editorialNote """commerce en général, voir E70
# commerce international, voir E71
# distribution et commercialisation de produits agricoles, voir E70
# économie de la consommation, voir E73"""@fr ;
#     skos:prefLabel "Domestic trade"@en,
#         "Commerce intérieur"@fr ;
#     skos:scopeNote """Commerce intérieur comprenant les activités liées au passage des produits agricoles de base et des produits utilisés pour la production agricole, du producteur au consommateur, à l'intérieur d'un pays
# Commerce national et local"""@fr .
#
# agrist:F62 a skos:Concept ;
#     rdfs:seeAlso agrist:F01,
#         agrist:F03,
#         agrist:H10,
#         agrist:H20,
#         agrist:H60,
#         agrist:L72,
#         agrist:L73 ;
#     skos:broader agrist:F ;
#     skos:editorialNote """méthodes de contrôle de la croissance des plantes, voir F01
# aptitude à la germination des semences, voir F03
# croissance et développement des mauvaises herbes, voir H60
# croissance et développement des organismes utilisés dans la lutte contre les bioagresseurs, voir H10, H20, L72, L73"""@fr ;
#     skos:prefLabel "Plant physiology - Growth and development"@en,
#         "Physiologie végétale - Croissance et développement"@fr ;
#     skos:scopeNote """Croissance et développement des plantes utiles (y compris les arbres forestiers et les plantes aquatiques)
# Germination, morphogenèse, formation et développement d'organes, formation et développement de la graine cicatrisation, abscission, sénescence des plantes (etc.), physiologie des plantes après récolte"""@fr .
#
# agrist:L01 a skos:Concept ;
#     rdfs:seeAlso agrist:E20,
#         agrist:E70,
#         agrist:H10,
#         agrist:H20,
#         agrist:J13,
#         agrist:L02,
#         agrist:L10,
#         agrist:L50,
#         agrist:L51,
#         agrist:L52,
#         agrist:L53,
#         agrist:L70,
#         agrist:L72,
#         agrist:L73,
#         agrist:L74,
#         agrist:M11,
#         agrist:M12,
#         agrist:N10 ;
#     skos:broader agrist:L ;
#     skos:editorialNote """alimentation des animaux (à l'exclusion des animaux aquatiques et des organismes utilisés dans la lutte contre les organismes nuisibles et les maladies), voir L02
# alimentation des animaux aquatiques, voir M12
# alimentation des organismes utilisés dans la lutte contre les organismes nuisibles et les maladies, voir H10, H20, L72, L73
# amélioration des animaux, voir L10
# aquaculture animale, voir M12
# distribution et commercialisation des produits d'origine animale, voir E70
# élevage d'organismes utilisés dans la lutte contre les organismes nuisibles et les maladies, voir H10, H20, L72, L73
# gestion de l'exploitation agricole, voir E20
# logement des animaux (constructions), voir N10
# manutention, transport, stockage et conservation des produits d'origine animale, voir J13
# physiologie et biochimie animales, voir L50-L53
# production d'animaux aquatiques, voir M12
# production de la pêche, voir M11
# protection des animaux, voir L70-L74"""@fr ;
#     skos:prefLabel "Animal husbandry"@en,
#         "Élevage - Considérations générales"@fr ;
#     skos:scopeNote """Élevage en général ; production et soins aux animaux utiles (à l'exclusion des animaux aquatiques et des organismes utilisés dans la lutte contre les organismes nuisibles et les maladies)
# Dressage, testage, sexage, marquage au fer et autres moyens pour identifier, exposer, juger les animaux
# Méthodes d'élevage des animaux utiles (autres que les animaux d'aquaculture et les organismes utilisés dans la lutte contre les organismes nuisibles et les maladies)
# Systèmes d'élevage : élevage protégé, en batterie, en liberté, extensif, intensif, à grande échelle, au sol, sur litière profonde; hivernage, sous abri
# Production de bétail : ânes, chevaux, bovins, buffles, chameaux, chèvres, porcs, moutons, etc. ; production de viande
# Production de lait, traite
# Aviculture : élevage de volailles, production d'œufs, production de viande de volaille
# Apiculture : élevage d'abeilles domestiques, conduite de la ruche, production de miel
# Sériciculture : élevage de vers à soie, production de soie
# Élevage d'autres animaux, tels que les animaux à fourrure, etc.
# Techniques d'abattage
# Rendements : quantité de produits ou de leurs dérivés découlant de l'élevage des animaux, poids à l'abattage, poids de carcasse ; récolte de produits d'origine animale"""@fr .
#
# agrist:L20 a skos:Concept ;
#     rdfs:seeAlso agrist:H10,
#         agrist:H20,
#         agrist:L72,
#         agrist:L73,
#         agrist:L74,
#         agrist:M40,
#         agrist:P01 ;
#     skos:broader agrist:L ;
#     skos:editorialNote """conservation des animaux, gestion de la faune sauvage, réserves de chasse et inventaires de gibier, chasse et pêche sportives, voir P01
# écologie des animaux aquatiques, voir M40
# écologie des organismes nuisibles, voir H10, L72
# écologie des organismes utilisés dans la lutte contre les organismes nuisibles et les maladies, voir H10, H20, L72, L73
# résistance des animaux au climat, aux conditions extrêmes, voir L74"""@fr ;
#     skos:prefLabel "Animal ecology"@en,
#         "Écologie animale"@fr ;
#     skos:scopeNote """Animaux utiles (à l'exclusion des animaux aquatiques et des organismes utilisés dans la lutte contre les organismes nuisibles et les maladies) en relation avec leur environnement ; écologie, phénologie
# Biologie du milieu ; effets des influences extérieures sur les processus biologiques chez les animaux terrestres utiles
# Comportement des animaux ; communication ; instinct ; apprentissage
# Habitat ; structure des populations animales
# Facteurs climatiques saisonniers : hibernation, migration
# Communautés animales, colonies, symbiose, etc."""@fr .
#
# agrist:L53 a skos:Concept ;
#     rdfs:seeAlso agrist:H10,
#         agrist:H20,
#         agrist:L10,
#         agrist:L40,
#         agrist:L70,
#         agrist:L72,
#         agrist:L73,
#         agrist:L74 ;
#     skos:broader agrist:L ;
#     skos:editorialNote """anatomie et morphologie du système reproducteur, voir L40
# génétique et amélioration des animaux, voir L10
# intervention chirurgicale à la parturition (obstétrique), voir L70
# physiologie de la reproduction des organismes nuisibles, voir H10, L72
# physiologie de la reproduction des organismes utilisés dans la lutte contre les organismes nuisibles et les maladies, voir H10, H20, L72, L73
# troubles de la reproduction chez les animaux, voir L74"""@fr ;
#     skos:prefLabel "Animal physiology - Reproduction"@en,
#         "Physiologie animale - Reproduction"@fr ;
#     skos:scopeNote """Physiologie de la reproduction des animaux utiles aquatiques et terrestres (à l'exclusion des organismes utilisés dans la lutte contre les organismes nuisibles et les maladies)
# Spermatogenèse, ovogenèse, hormones sexuelles, œstrus, ovulation, gestation, parturition, fertilité, etc."""@fr .
#
# agrist:P05 a skos:Concept ;
#     rdfs:seeAlso agrist:N01,
#         agrist:P06,
#         agrist:P07 ;
#     skos:broader agrist:P ;
#     skos:editorialNote """électrification rurale, génies électrique et électronique, voir N01
# sources d'énergie non-renouvelable, voir P07
# sources d'énergie renouvelable, voir P06"""@fr ;
#     skos:prefLabel "Energy resources management"@en,
#         "Ressources énergétiques et leur gestion"@fr ;
#     skos:scopeNote """Politique de l'énergie ; état de la situation énergétique
# Économie de l'énergie, offre et demande; substances énergétiques, comptabilité énergétique, budget, subvention, coût ; flux d'énergie, ratio énergétique
# Conservation, besoins et utilisation de l'énergie (y compris l'énergie des animaux de trait et de la traction animale) pour la production, la transformation, la commercialisation et le transport des produits agricoles
# Stockage de l'énergie ; matériel pour la transformation de l'énergie ; distribution de l'énergie
# Centrales électriques utilisées par l'agriculture et le monde rural"""@fr .
#
# agrist:P32 a skos:Concept ;
#     rdfs:seeAlso agrist:P31,
#         agrist:P36 ;
#     skos:broader agrist:P ;
#     skos:editorialNote """érosion du sol, voir P36
# levés des sols, voir P31"""@fr ;
#     skos:prefLabel "Soil classification and genesis"@en,
#         "Classification des sols et pédogenèse"@fr ;
#     skos:scopeNote """Distribution spatiale des sols ; classification génétique (zonale) et texturale
# Profils de sol ; horizons et profondeur du sol
# Formation du sol ; altérations du sol dues aux intempéries, sols d'apport, âge des sols"""@fr .
#
# agrist:S40 a skos:Concept ;
#     rdfs:seeAlso agrist:E10,
#         agrist:E14,
#         agrist:S20,
#         agrist:S30 ;
#     skos:broader agrist:S ;
#     skos:editorialNote """aide alimentaire, voir E14
# normes nutritionnelles, voir S30
# physiologie de la nutrition humaine, voir S20
# planification des stocks alimentaires, politique d'approvisionnement alimentaire, voir E10
# régimes et maladies nutritionnelles, voir S30"""@fr ;
#     skos:prefLabel "Nutrition programmes"@en,
#         "Programmes alimentaires"@fr ;
#     skos:scopeNote """Planification, politique, administration de programmes alimentaires ; impacts et évaluation des programmes
# Programmes alimentaires communautaires
# Programmes d'alimentation infantile : repas scolaires, distribution de lait"""@fr .
#
# agrist:E13 a skos:Concept ;
#     rdfs:seeAlso agrist:E10,
#         agrist:E11,
#         agrist:E20,
#         agrist:E21,
#         agrist:E80,
#         agrist:E90 ;
#     skos:broader agrist:E ;
#     skos:editorialNote """comptes et budgets familiaux, voir E80
# économie agricole en général, voir E10
# entreprises agricoles, voir E20
# imposition des terres, voir E11
# industries agricoles, voir E21
# structure agraire, voir E90"""@fr ;
#     skos:prefLabel "Investment, finance and credit"@en,
#         "Investissements, financement et crédit"@fr ;
#     skos:scopeNote """Finances : aspects monétaires des activités agricoles en général, y compris la circulation monétaire, l'octroi de crédits, les opérations d'investissement et la prestation de services bancaires. Microfinancement, microcrédit
# Aides et subventions agricoles : prêts gouvernementaux aux entreprises agricoles pour l'amélioration des exploitations ou des terres agricoles, dans le but d'accroître la production et la qualité des produits agricoles de base
# Coopératives de crédit agricole chargées de l'octroi de prêts basés sur un capital investi provenant de leurs membres et divisé en actions, chaque action représentant un droit de propriété proportionnel dans ce type de société"""@fr .
#
# agrist:E51 a skos:Concept ;
#     rdfs:seeAlso agrist:E50 ;
#     skos:broader agrist:E ;
#     skos:editorialNote "migration rurale, nomadisme, colonisation agraire, voir E50"@fr ;
#     skos:prefLabel "Rural population"@en,
#         "Population rurale"@fr ;
#     skos:scopeNote """Politique concernant la population rurale, y compris la régulation des naissances, le planning familial
# Structure, composition, répartition de la population rurale
# Dynamique de la population rurale : accroissement, baisse de la population, densité de population, équilibre de la population
# Recensements, études, statistiques de population rurale"""@fr .
#
# agrist:F03 a skos:Concept ;
#     rdfs:seeAlso agrist:E21,
#         agrist:F02,
#         agrist:F62,
#         agrist:K10 ;
#     skos:broader agrist:F ;
#     skos:editorialNote """germination des semences, voir F62
# industrie des semences, voir E21
# multiplication d'arbres forestiers, voir K10
# multiplication végétative des plantes, voir F02
# production et traitement des semences forestières, voir K10"""@fr ;
#     skos:prefLabel "Seed production and processing"@en,
#         "Production et traitement des semences"@fr ;
#     skos:scopeNote """Production de semences pour la multiplication et traitement des semences (à l'exclusion de la production et du traitement des semences forestières)
# Traitement des semences : nettoyage, inoculation, enrobage, scarification, stratification, scarification du testa de la graine, etc. ; tests des semences, essais des semences, certification des semences ; contrôle de la qualité des semences
# Aptitude à la germination
# Stockage des semences"""@fr .
#
# agrist:F07 a skos:Concept ;
#     rdfs:seeAlso agrist:F01,
#         agrist:F04,
#         agrist:F08,
#         agrist:H60,
#         agrist:K10,
#         agrist:N20,
#         agrist:P36 ;
#     skos:broader agrist:F ;
#     skos:editorialNote """amélioration du sol, voir F04
# brûlage contrôlé ou dirigé en forêt, voir K10
# conservation du sol, voir P36
# culture des plantes, voir F01
# désherbage, voir H60
# emploi des engrais, voir F04
# matériel pour le travail du sol, voir N20
# systèmes avec jachère, voir F08
# systèmes de culture, voir F08"""@fr ;
#     skos:prefLabel "Soil cultivation"@en,
#         "Travail du sol"@fr ;
#     skos:scopeNote "Préparation du sol pour la culture des plantes : travail du sol, hersage, roulage, labour, mise en jachère, paillage, stérilisation, désinfection (état sanitaire du sol), brûlage, préparation du lit de semences, etc."@fr .
#
# agrist:F63 a skos:Concept ;
#     rdfs:seeAlso agrist:F02,
#         agrist:F30,
#         agrist:H10,
#         agrist:H20,
#         agrist:H60,
#         agrist:K10,
#         agrist:L72,
#         agrist:L73 ;
#     skos:broader agrist:F ;
#     skos:editorialNote """génétique et amélioration des plantes, voir F30
# multiplication des arbres forestiers, voir K10
# multiplication des plantes, voir F02
# ...
# micro-organismes utiles des aliments pour animaux, voir Q52
# protection des aliments pour animaux, voir J10-J14
# qualité des aliments pour animaux, voir Q54
# stockage des aliments pour animaux, voir J10-J14"""@fr ;
#     skos:prefLabel "Feed contamination and toxicology"@en,
#         "Contamination et toxicologie des aliments pour animaux"@fr ;
#     skos:scopeNote """Micro-organismes nuisibles des aliments pour animaux
# Toxicologie, adultération, contamination, détérioration des aliments pour animaux
# Altération ; agents pathogènes des aliments pour animaux
# Inspection, contrôle sanitaire des aliments pour animaux"""@fr .
#
# agrist:K10 a skos:Concept ;
#     rdfs:seeAlso agrist:E20,
#         agrist:E70,
#         agrist:F06,
#         agrist:F08,
#         agrist:F30,
#         agrist:F40,
#         agrist:F50,
#         agrist:H10,
#         agrist:H20,
#         agrist:H60,
#         agrist:J12,
#         agrist:K11,
#         agrist:K70,
#         agrist:N20,
#         agrist:P11,
#         agrist:U30 ;
#     skos:broader agrist:K ;
#     skos:editorialNote """anatomie et morphologie des arbres forestiers, voir F50
# agroforesterie, voir F08
# classement, norme, marquage de produits forestiers, voir E70
# conservation des produits forestiers, voir J12
# désherbage, voir H60
# distribution et commercialisation des produits forestiers, voir E70
# drainage, voir P11
# écologie forestière, voir F40
# génétique des arbres, voir F30
# génie forestier, voir K11
# incendies de forêt, voir K70
# irrigation, voir F06
# maladies des arbres forestiers, voir H20
# matériels et équipements forestiers, voir N20
# méthodes de relevé, voir U30
# organisation, administration et gestion des entreprises forestières, voir E20
# bioagresseurs des arbres forestiers, voir H10"""@fr ;
#     skos:prefLabel "Forestry production"@en,
#         "Production forestière"@fr ;
#     skos:scopeNote """Opérations forestières (y compris l'abattage et l'arrachage des arbres) ; méthodes de production forestière en général, forêts expérimentales, privées, paysannes, etc.
# Dendrométrie : systèmes et unités de mesure pour les dimensions des troncs et le volume des arbres, peuplements, forêts et bois ; tables d'accroissement et de production forestières ; modèles informatiques pour peuplement forestier
# Estimation de la qualité de la station ; cartographie forestière, inventaires et reconnaissance
# Foresterie urbaine ; ceintures de protection et brise-vents
# Entretien des forêts pour la sylviculture extensive ; méthodes de sylviculture intensive
# Régime sylvicole, rotation sylvicole, éclaircie, coupe rase, système de sélection, amélioration des peuplements forestiers, contrôle de la croissance et de la composition des forêts, formation des peuplements, régime de futaie
# Renouvellement par : reproduction naturelle par graine ou reproduction végétative, coupe de rajeunissement, régénération naturelle, régénération par coupe ou par abattage, etc. ; renouvellement par ensemencement ou plantation, régénération artificielle, boisement et reboisement, pépinières, plants élevés en conteneur, semis direct, plantation en sous étage, plantation d'abri, etc.
# Brûlage dirigé ou contrôlé des forêts
# Plantations forestières ; production d'arbres d'ombrage, d'ornement, de Noël
# Production et traitement des semences forestières
# Rendements forestiers : quantité de produits ou de leurs dérivés découlant de la production forestière ; abattage et débardage du bois et autres formes de récolte de produits forestiers"""@fr .
#
# agrist:Q03 a skos:Concept ;
#     rdfs:seeAlso agrist:D50,
#         agrist:J10,
#         agrist:J11,
#         agrist:J12,
#         agrist:J13,
#         agrist:J14,
#         agrist:Q02,
#         agrist:Q04,
#         agrist:Q53 ;
#     skos:broader agrist:Q ;
#     skos:editorialNote """conservation des produits alimentaires, voir Q02
# contamination et toxicologie des aliments pour animaux, voir Q53
# législation concernant le contrôle de la qualité des produits alimentaires, voir D50
# micro-organismes utiles des produits alimentaires, voir Q02
# protection des produits alimentaires, voir J10-J14
# qualité des produits alimentaires, voir Q04
# stockage des produits alimentaires, voir J10-J14"""@fr ;
#     skos:prefLabel "Food contamination"@en,
#         "Contamination et toxicologie alimentaires"@fr ;
#     skos:scopeNote """Micro-organismes nuisibles des produits alimentaires
# Toxicologie et altération des produits alimentaires : défauts, agents pathogènes, adultération, contamination détérioration
# Santé publique et produits alimentaires : inspection des viandes, hygiène alimentaire, lutte contre les agents pathogènes des aliments, etc."""@fr .
#
# agrist:L72 a skos:Concept ;
#     rdfs:seeAlso agrist:D50,
#         agrist:H02,
#         agrist:J13,
#         agrist:L10,
#         agrist:L73,
#         agrist:L74,
#         agrist:N20,
#         agrist:S50 ;
#     skos:broader agrist:L ;
#     skos:editorialNote """conservation des produits stockés d'origine animale, voir J13
# maladies des animaux, voir L73
# matériels de lutte contre les organismes nuisibles des animaux, voir N20
# propriété et examen des agents pathogènes des animaux, des organismes provoquant des maladies, voir L73
# réglementation de quarantaine des animaux, voir D50
# sélection pour la résistance des animaux aux organismes nuisibles, voir L10
# toxicité des pesticides pour les êtres humains, voir S50
# toxicité des pesticides pour les animaux d'élevage, voir L74
# toxicité des pesticides pour les plantes utiles, voir H02
# troubles physiologiques et génétiques des animaux, voir L74"""@fr ;
#     skos:prefLabel "Pests of animals"@en,
#         "Organismes nuisibles des animaux"@fr ;
#     skos:scopeNote """Ne comprend pas l'information dans laquelle les organismes nuisibles des animaux sont utilisés pour l'étude des processus biologiques généraux, par exemple la génétique, et qui n'a pas de relation directe avec la lutte menée contre eux ou avec les blessures ou les irritations infligées par ces organismes aux animaux utiles
# Organismes nuisibles des animaux utiles aquatiques et terrestres, tels que parasites, prédateurs ou vecteurs d'agents pathogènes
# Insectes, acariens, tiques, helminthes, protozoaires, oiseaux, mammifères nuisibles aux animaux utiles aquatiques et terrestres
# Moyens, méthodes et programmes de lutte contre les organismes nuisibles des animaux (y compris la lutte culturale, chimique, physique, mécanique, intégrée et biologique) ; élevage d'organismes utilisés dans la lutte contre les organismes nuisibles des animaux ; génétique, écologie, anatomie, morphologie, physiologie, biochimie et taxonomie des organismes de lutte
# Inventaire des organismes nuisibles
# Immunité : résistance des animaux aux organismes nuisibles, résistance des organismes nuisibles aux pesticides, etc. ; immunisation
# Écologie, anatomie, physiologie, biochimie et taxonomie des organismes nuisibles des animaux"""@fr .
#
# agrist:L73 a skos:Concept ;
#     rdfs:seeAlso agrist:D50,
#         agrist:H02,
#         agrist:J13,
#         agrist:L10,
#         agrist:L72,
#         agrist:L74,
#         agrist:N20,
#         agrist:S50 ;
#     skos:broader agrist:L ;
#     skos:editorialNote """conservation des produits stockés d'origine animale, voir J13
# maladies de carence des animaux, voir L74
# matériels de lutte contre les maladies des animaux, voir N20
# organismes nuisibles des animaux, voir L72
# réglementation de quarantaine des animaux, voir D50
# santé humaine, voir S50
# sélection pour la résistance des animaux aux maladies, voir L10
# toxicité des pesticides pour les êtres humains, voir S50
# toxicité des pesticides pour les animaux d'élevage, voir L74
# toxicité des pesticides pour les plantes utiles, voir H02
# troubles génétiques des animaux, voir L74
# troubles nutritionnels des animaux, voir L74
# troubles physiologiques des animaux, voir L74
# zoonoses (maladies des animaux transmissibles entre les animaux et les êtres humains), voir S50"""@fr ;
#     skos:prefLabel "Animal diseases"@en,
#         "Maladies des animaux"@fr ;
#     skos:scopeNote """Maladies des animaux utiles aquatiques et terrestres et les organismes qui les provoquent : bactéries, champignons, mycoplasmes, virus, etc.
# Zoonoses (maladies des animaux transmissibles entre les animaux et les êtres humains)
# Moyens, méthodes et programmes de lutte contre les maladies des animaux (y compris la lutte culturale, chimique, physique, mécanique, intégrée et biologique) ; élevage d'organismes utilisés dans la lutte contre les maladies des animaux ; génétique, écologie, anatomie, morphologie, physiologie, biochimie et taxonomie des organismes de lutte
# Enquête épidémiologique sur les animaux
# Immunité : résistance des animaux aux infections; résistance des agents pathogènes aux pesticides, etc. ; immunisation
# Propriété et examen des agents pathogènes des animaux, des organismes provoquant des maladies"""@fr .
#
# agrist:D50 a skos:Concept ;
#     rdfs:seeAlso agrist:E70,
#         agrist:L70,
#         agrist:Q03,
#         agrist:Q53 ;
#     skos:broader agrist:D ;
#     skos:editorialNote """classement, normes, étiquetage de contenu, voir E70
# hygiène, vétérinaire, voir L70
# inspection et contrôle sanitaire des aliments (alimentation humaine), voir Q03
# inspection et contrôle sanitaire des aliments pour animaux, voir Q53"""@fr ;
#     skos:prefLabel "Legislation"@en,
#         "Législation"@fr ;
#     skos:scopeNote """Droit agricole émanant des autorités gouvernementales et intergouvernementales
# Réglementation des importations et des exportations, réglementation douanière
# Réglementation de quarantaine des animaux et de quarantaine des plantes
# Brevets
# Législation sur les droits des sélectionneurs (ou obtenteurs) : inscription et brevets de variétés végétales et de races animales
# Aspects législatifs des contrôles de la qualité, réglementation sanitaire
# Aspects législatifs de la lutte antipollution ; réglementation relative aux résidus toxiques
# Réglementation relative au classement des produits
# Droit des eaux"""@fr .
#
# agrist:E70 a skos:Concept ;
#     rdfs:seeAlso agrist:E71,
#         agrist:E72,
#         agrist:E73,
#         agrist:J,
#         agrist:Q,
#         agrist:Q03,
#         agrist:Q53,
#         agrist:Q80 ;
#     skos:broader agrist:E ;
#     skos:editorialNote """commerce intérieur, voir E72
# commerce international, voir E71
#  conditionnement, voir Q80
#  conservation des produits agricoles, voir J10-J15
#  économie de la consommation, voir E73
#  inspection sanitaire des aliments pour animaux, voir Q53
#  inspection sanitaire des produits alimentaires, voir Q03
#  prix communautaires garantis dans le commerce international, voir E71
#  stockage des produits agricoles, voir J10-J15
#  traitement des produits agricoles, voir Q01-Q80
#  transport des produits agricoles, voir J10-J15"""@fr ;
#     skos:prefLabel "Trade, marketing and distribution"@en,
#         "Commerce, commercialisation et distribution"@fr ;
#     skos:scopeNote """Commerce : échange, achat ou vente de produits agricoles de base ou des produits utilisés pour la production agricole
# Commercialisation, y compris les activités en relation avec le passage des produits agricoles de base ou des produits utilisés pour la production agricole, du producteur au consommateur, telles que la coordination de la fabrication, la normalisation, l'achat, la vente, la promotion des ventes, la publicité, l'expédition, la distribution ; commerces de gros et de détail ; vente aux enchères et autres méthodes de vente ; foires commerciales et expositions
# Politique, coûts et méthodes de distribution
# Offre et demande ; étude et analyse de marchés, prévision des ventes, modèles économétriques concernant les marchés
# Fixation et stabilisation des prix
# Qualité, norme et étiquetage de contenu ; marque de fabrique utilisée pour l'identification des produits commercialisés
# Classement : classification des produits agricoles suivant les normes d'uniformité, de taille, d'absence de défauts ou de maladies, de finesse, de qualité, etc."""@fr .
#
# agrist:H10 a skos:Concept ;
#     rdfs:seeAlso agrist:D50,
#         agrist:F30,
#         agrist:H01,
#         agrist:H02,
#         agrist:H20,
#         agrist:H50,
#         agrist:H60,
#         agrist:J11,
#         agrist:J12,
#         agrist:L74,
#         agrist:N20,
#         agrist:S50 ;
#     skos:broader agrist:H ;
#     skos:editorialNote """amélioration des plantes pour la résistance aux ravageurs, voir F30
# conservation des produits d'origine végétale, voir J11
# effets phytotoxiques des pesticides, voir H02
# maladies des plantes, voir H20
# matériel de lutte contre les organismes nuisibles des plantes, voir N20
# mauvaises herbes et désherbage, voir H60
# préservation du bois, voir J12
# propriété et examen des agents pathogènes des plantes, des organismes provoquant des maladies, voir H20
# protection des plantes en général, voir H01
# réglementation de quarantaine des plantes, voir D50
# toxicité des pesticides pour l'être humain, voir S50
# toxicité des pesticides pour les animaux utiles, voir L74
# toxicité des pesticides pour les plantes utiles, voir H02
# troubles physiologiques et génétiques des plantes, voir H50"""@fr ;
#     skos:prefLabel "Pests of plants"@en,
#         "Ravageurs des plantes"@fr ;
#     skos:scopeNote """Ne concerne pas les bioagresseurs utilisés pour l'étude des phénomènes biologiques généraux, par exemple la génétique, et qui n'ont pas de relation directe avec la lutte menée contre eux, ou sur les dégâts ou pertes de récolte qu'ils causent
# Ravageurs (ou organismes nuisibles, ou bioagresseurs) des plantes utiles (y compris les arbres forestiers et les plantes aquatiques) et les dégâts qu'ils provoquent
# Insectes, acariens, nématodes, protozoaires, mollusques, oiseaux, mammifères, etc., nuisibles aux plantes utiles ou vecteurs d'agents pathogènes des plantes
# Moyens, méthodes et programmes de lutte contre les ravageurs (y compris la lutte culturale, chimique, physique, mécanique, intégrée et biologique) ; élevage d'organismes utilisés dans la lutte contre les ravageurs ; génétique, écologie, anatomie, morphologie, physiologie, biochimie et taxonomie des organismes de lutte
# Inventaires des ravageurs des plantes
# Immunité : résistance des plantes aux ravageurs, résistance des ravageurs aux pesticides
# Écologie, anatomie, morphologie, biochimie et taxonomie des ravageurs"""@fr .
#
# agrist:H20 a skos:Concept ;
#     rdfs:seeAlso agrist:D50,
#         agrist:F30,
#         agrist:H02,
#         agrist:H10,
#         agrist:H50,
#         agrist:H60,
#         agrist:J11,
#         agrist:J12,
#         agrist:L74,
#         agrist:N20,
#         agrist:S50 ;
#     skos:broader agrist:H ;
#     skos:editorialNote """amélioration des plantes pour la résistance aux maladies, voir F30
# conservation des produits d'origine végétale, voir J11
# maladies de carence des plantes, voir H60
# matériel de lutte contre les maladies des plantes, voir N20
# mauvaises herbes et désherbage, voir H60
# préservation du bois, voir J12
# ravageurs des plantes, voir H10
# réglementation de quarantaine des plantes, voir D50
# toxicité des pesticides pour l'être humain, voir S50
# toxicité des pesticides pour les animaux utiles, voir L74
# toxicité des pesticides pour les plantes utiles, voir H02
# troubles nutritionnels des plantes, voir H50
# troubles physiologiques et génétiques des plantes, voir H50"""@fr ;
#     skos:prefLabel "Plant diseases"@en,
#         "Maladies des plantes"@fr ;
#     skos:scopeNote """Pathologie végétale (bioagresseurs) ; maladies des plantes utiles (y compris les arbres forestiers et les plantes aquatiques) et organismes qui les provoquent: bactéries, champignons, mycoplasmes, virus, etc.
# Moyens, méthodes et programmes de lutte contre les maladies des plantes (y compris la lutte culturale, chimique, physique, mécanique, intégrée et biologique) ; élevage d'organismes utilisés dans la lutte contre les maladies des plantes ; génétique, écologie, anatomie, morphologie, physiologie, biochimie et taxonomie des organismes utilisés dans la lutte
# Inventaire des maladies des plantes
# Immunité : résistance des plantes aux infections ; résistance des agents pathogènes des plantes aux pesticides
# Propriété et examen des agents pathogènes des plantes, organismes provoquant des maladies"""@fr .

# %%
serialize_Graph(g, agrist_ttl, append=True)
